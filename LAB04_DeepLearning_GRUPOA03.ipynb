# %% [markdown]
# # Práctica final Deep Learning: Poemas de Antonio Machado

# %% [markdown]
# ## Objetivo

# %% [markdown]
# Desarrollo de una IA generativa capaz de generar poemas de Antonio Machado. Para ello se debe coger un archivo donde se puedan encontrar poemas de Antonio Machado con los que entrenar el modelo.
#
# **Autores**
# Ana Alonso Cañizares
# Álvaro García Cid
# Álvaro García Parra

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### Implementación de librerías y funciones a utilizar

# %%
pip install fitz
# Out:
# Requirement already satisfied: fitz in /usr/local/lib/python3.10/dist-packages (0.0.1.dev2)
# Requirement already satisfied: configobj in /usr/local/lib/python3.10/dist-packages (from fitz) (5.0.8)
# Requirement already satisfied: configparser in /usr/local/lib/python3.10/dist-packages (from fitz) (7.0.0)
# Requirement already satisfied: httplib2 in /usr/local/lib/python3.10/dist-packages (from fitz) (0.22.0)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from fitz) (4.0.2)
# Requirement already satisfied: nipype in /usr/local/lib/python3.10/dist-packages (from fitz) (1.8.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from fitz) (2.0.3)
# Requirement already satisfied: pyxnat in /usr/local/lib/python3.10/dist-packages (from fitz) (1.6.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from fitz) (1.11.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from configobj->fitz) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2->fitz) (3.1.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (24.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->fitz) (67.7.2)
# Requirement already satisfied: click>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (8.1.7)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.3)
# Requirement already satisfied: prov>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (2.0.0)
# Requirement already satisfied: pydot>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.2 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (2.8.2)
# Requirement already satisfied: rdflib>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (7.0.0)
# Requirement already satisfied: simplejson>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.19.2)
# Requirement already satisfied: traits!=5.0,<6.4,>=4.6 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (6.3.2)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (3.14.0)
# Requirement already satisfied: etelemetry>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (0.3.1)
# Requirement already satisfied: looseversion in /usr/local/lib/python3.10/dist-packages (from nipype->fitz) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fitz) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->fitz) (2024.1)
# Requirement already satisfied: lxml>=4.3 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (4.9.4)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (2.31.0)
# Requirement already satisfied: pathlib>=1.0 in /usr/local/lib/python3.10/dist-packages (from pyxnat->fitz) (1.0.1)
# Requirement already satisfied: ci-info>=0.2 in /usr/local/lib/python3.10/dist-packages (from etelemetry>=0.2.0->nipype->fitz) (0.3.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from rdflib>=5.0.0->nipype->fitz) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->pyxnat->fitz) (2024.2.2)

# %%
pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.10/dist-packages (1.24.3)
# Requirement already satisfied: PyMuPDFb==1.24.3 in /usr/local/lib/python3.10/dist-packages (from pymupdf) (1.24.3)

# %%
import fitz     # Para guardar en una variable los poemas encontrados en el documento
import re       # Tenemos en cuenta los saltos de línea como una palabra más
import string   # Para customizar la estandarización más adelante en la vectorización
import random

# Librerías necesarias para el desarrollo del modelo deep learning
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import tensorflow as tf

# %%
# Abrimos el fichero
pdf_doc = fitz.open("Poemas_Antonio_Machado.docx")

poemas = []

# En cada página del fichero se encuentra un poema
for page in pdf_doc:
  text = page.get_text()
  poemas.extend(text.strip().split("\n\n"))

# Observamos lo que se ha guardado
poemas
# Out:
# ['Está en la sala familiar, sombría,\ny entre nosotros, el querido hermano\nque en el sueño infantil de un claro día\nvimos partir hacia un país lejano.\nHoy tiene ya las sienes plateadas,\nun gris mechón sobre la angosta frente;\ny la fría inquietud de sus miradas\nrevela un alma casi toda ausente.\nDeshójanse las copas otoñales\ndel parque mustio y viejo.\nLa tarde, tras los húmedos cristales,\nse pinta, y en el fondo del espejo.\nEl rostro del hermano se ilumina\nsuavemente. ¿Floridos desengaños\ndorados por la tarde que declina?\n¿Ansias de vida nueva en nuevos años?\n¿Lamentará la juventud perdida?\nLejos quedó —la pobre loba— muerta.\n¿La blanca juventud nunca vivida\nteme, que ha de cantar ante su puerta?\n¿Sonríe al sol de oro,\nde la tierra de un sueño no encontrada;',
#  'donde habitaba ella,\nsobre un montón de escombros arruinada\no derruida, enseña\nel negro y carcomido\nmal trabado esqueleto de madera.\nLa luna está vertiendo\nsu clara luz en sueños que platea\nen las ventanas. Mal vestido y triste,\nvoy caminando por la calle vieja.\nAnte el pálido lienzo de la tarde,\nla iglesia, con sus torres afiladas\ny el ancho campanario, en cuyos huecos\nvoltean suavemente las campanas,\nalta y sombría, surge.\nLa estrella es una lágrima\nen el azul celeste.\nBajo la estrella clara,\nflota, vellón disperso,\nuna nube quimérica de plata.\n¡Oh tarde luminosa!',
#  'El aire está encantado.\nLa blanca cigüeña\ndormita volando,\ny las golondrinas se cruzan, tendidas\nlas alas agudas al viento dorado,\ny en la tarde risueña se alejan\nvolando, soñando...\nY hay una que torna como la saeta,\nlas alas agudas tendidas al aire sombrío,\nbuscando su negro rincón del tejado.\nLa blanca cigüeña,\ncomo un garabato,\ntranquila y disforme, ¡tan disparatada!\nsobre el campanario.\n¿Y ha de morir contigo el mundo\ndonde guarda el recuerdo\nlos hálitos más puros de la vida,\nla blanca sombra del amor primero,\nla voz que fue a tu corazón, la mano\nque tú querías retener en sueños,\ny todos los amores',
#  'que llegaron al alma, al hondo cielo?\n¿Y ha de morir contigo el mundo tuyo,\nla vieja vida en orden tuyo y nuevo?\n¿Los yunques y crisoles de tu alma\ntrabajan para el polvo y para el viento?\nDesnuda está la tierra,\ny el alma aúlla al horizonte pálido\ncomo loba famélica. ¿Qué buscas,\npoeta, en el ocaso?\nAmargo caminar, porque el camino\npesa en el corazón. ¡El viento helado,\ny la noche que llega, y la amargura\nde la distancia!... En el camino blanco\nalgunos yertos árboles negrean;\nen los montes lejanos\nhay oro y sangre ... El sol murió... ¿Qué buscas\npoeta, en el ocaso?\nLa tarde está muriendo\ncomo un hogar humilde que se apaga.\nAllá, sobre los montes,',
#  'quedan algunas brasas.\nY ese árbol roto en el camino blanco\nhace llorar de lástima.\n¡Dos ramas en el tronco herido, y una\nhoja marchita y negra en cada rama!\n¿Lloras?... Entre los álamos de oro,\nlejos, la sombra del amor te aguarda.\nEl hada más hermosa ha sonreído\nal ver la lumbre de una estrella pálida,\nque en hilo suave, blanco y silencioso\nse enrosca al huso de su rubia hermana.\nY vuelve a sonreír, porque en su rueca\nel hilo de los campos se enmaraña.\nTras la tenue cortina de la alcoba\nestá el jardín envuelto en luz dorada.\nLa cuna, casi en sombra. El niño duerme.\nDos hadas laboriosas lo acompañan,\nhilando de los sueños los sutiles\ncopos en ruecas de marfil y plata.\nGuitarra del mesón que hoy suenas jota,',
#  'mañana petenera,\nsegún quien llega y tañe\nlas empolvadas cuerdas,\nguitarra del mesón de los caminos,\nno fuiste nunca, ni serás, poeta.\nTú eres alma que dice su armonía\nsolitaria a las almas pasajeras...\nY siempre que te escucha el caminante\nsueña escuchar un aire de su tierra.\nLa primavera besaba\nsuavemente la arboleda,\ny el verde nuevo brotaba\ncomo una verde humareda.\nLas nubes iban pasando\nsobre el campo juvenil...\nYo vi en las hojas temblando\nlas frescas lluvias de abril.\nBajo ese almendro florido,\ntodo cargado de flor\n—recordé—, yo he maldecido\nmi juventud sin amor.',
#  'Hoy, en mitad de la vida,\nme he parado a meditar...\n¡Juventud nunca vivida\nquién te volviera a soñar!\nEran ayer mis dolores\ncomo gusanos de seda\nque iban labrando capullos;\nhoy son mariposas negras.\n¡De cuántas flores amargas\nha sacado blanca cera!\n¡Oh tiempo en que mis pesares\ntrabajaban como abejas!\nHoy son como avenas locas,\no cizaña en sementera,\ncomo tizón en espiga,\ncomo carcoma en madera.\n¡Oh tiempo en que mis dolores\ntenían lágrimas buenas,\ny eran como agua de noria\nque va regando una huerta!\nHoy son agua de torrente',
#  'que arranca el limo a la tierra.\nDolores que ayer hicieron\nde mi corazón colmena,\nhoy tratan mi corazón\ncomo a una muralla vieja:\nquieren derribarlo, y pronto,\nal golpe de la piqueta.\nHúmedo está, bajo el laurel, el banco\nde verdinosa piedra;\nlavó la lluvia, sobre el muro blanco,\nlas empolvadas hojas de la hiedra.\nDel viento del otoño el tibio aliento\nlos céspedes undula, y la alameda\nconversa con el viento...\n¡el viento de la tarde en la arboleda!\nMientras el sol en el ocaso esplende\nque los racimos de la vid orea,\ny el buen burgués, en su balcón, enciende\nla estoica pipa en que el tabaco humea,\nvoy recordando versos juveniles...\n¿Qué fue de aquel mi corazón sonoro?',
#  '¿Será cierto que os vais, sombras gentiles,\nhuyendo entre los árboles de oro?']

# %%
# Función que introduce un espacio antes y después de un "\n", o, lo que es lo mismo
# antes y después de cada salto de línea
def insert_spaces_before_after_newline(text):
    # Utiliza expresiones regulares para encontrar todas las ocurrencias de \n
    pattern = re.compile(r'(?<=\n)|(?=\n)')
    # Inserta un espacio antes y después de cada ocurrencia de \n
    modified_text = pattern.sub(' ', text)
    return modified_text

# Meter espacios alrededor de los saltos de línea
for i, poema in enumerate(poemas):
  poemas[i] = insert_spaces_before_after_newline(poemas[i])

poemas
# Out:
# ['Está en la sala familiar, sombría, \n y entre nosotros, el querido hermano \n que en el sueño infantil de un claro día \n vimos partir hacia un país lejano. \n Hoy tiene ya las sienes plateadas, \n un gris mechón sobre la angosta frente; \n y la fría inquietud de sus miradas \n revela un alma casi toda ausente. \n Deshójanse las copas otoñales \n del parque mustio y viejo. \n La tarde, tras los húmedos cristales, \n se pinta, y en el fondo del espejo. \n El rostro del hermano se ilumina \n suavemente. ¿Floridos desengaños \n dorados por la tarde que declina? \n ¿Ansias de vida nueva en nuevos años? \n ¿Lamentará la juventud perdida? \n Lejos quedó —la pobre loba— muerta. \n ¿La blanca juventud nunca vivida \n teme, que ha de cantar ante su puerta? \n ¿Sonríe al sol de oro, \n de la tierra de un sueño no encontrada;',
#  'mañana petenera, \n según quien llega y tañe \n las empolvadas cuerdas, \n guitarra del mesón de los caminos, \n no fuiste nunca, ni serás, poeta. \n Tú eres alma que dice su armonía \n solitaria a las almas pasajeras... \n Y siempre que te escucha el caminante \n sueña escuchar un aire de su tierra. \n La primavera besaba \n suavemente la arboleda, \n y el verde nuevo brotaba \n como una verde humareda. \n Las nubes iban pasando \n sobre el campo juvenil... \n Yo vi en las hojas temblando \n las frescas lluvias de abril. \n Bajo ese almendro florido, \n todo cargado de flor \n —recordé—, yo he maldecido \n mi juventud sin amor.',
#  'Hoy, en mitad de la vida, \n me he parado a meditar... \n ¡Juventud nunca vivida \n quién te volviera a soñar! \n Eran ayer mis dolores \n como gusanos de seda \n que iban labrando capullos; \n hoy son mariposas negras. \n ¡De cuántas flores amargas \n ha sacado blanca cera! \n ¡Oh tiempo en que mis pesares \n trabajaban como abejas! \n Hoy son como avenas locas, \n o cizaña en sementera, \n como tizón en espiga, \n como carcoma en madera. \n ¡Oh tiempo en que mis dolores \n tenían lágrimas buenas, \n y eran como agua de noria \n que va regando una huerta! \n Hoy son agua de torrente',
#  'que arranca el limo a la tierra. \n Dolores que ayer hicieron \n de mi corazón colmena, \n hoy tratan mi corazón \n como a una muralla vieja: \n quieren derribarlo, y pronto, \n al golpe de la piqueta. \n Húmedo está, bajo el laurel, el banco \n de verdinosa piedra; \n lavó la lluvia, sobre el muro blanco, \n las empolvadas hojas de la hiedra. \n Del viento del otoño el tibio aliento \n los céspedes undula, y la alameda \n conversa con el viento... \n ¡el viento de la tarde en la arboleda! \n Mientras el sol en el ocaso esplende \n que los racimos de la vid orea, \n y el buen burgués, en su balcón, enciende \n la estoica pipa en que el tabaco humea, \n voy recordando versos juveniles... \n ¿Qué fue de aquel mi corazón sonoro?',
#  '¿Será cierto que os vais, sombras gentiles, \n huyendo entre los árboles de oro?']

# %%
# Calcular el total de palabras en todos los poemas
total_palabras = sum(len(poema.split()) for poema in poemas)

# Calcular la media de palabras en total
media_palabras_total = total_palabras / len(poemas)

print("Media de palabras en total:", media_palabras_total)
# Out:
# Media de palabras en total: 109.71428571428571

# %%
max_length = round(media_palabras_total) # Tamaño de las secuencias
max_tokens = 1667  # Tamaño del vocabulario
batch_size = 4      # Tamaño del lote
embed_dim = 256     # Dimensión del embedding
num_heads = 2       # Número de cabezas del MultiHead
dense_dim = 32      # Nº de neuronas de la capa densa
EPOCHS = 30         # Nº de épocas

# %% [markdown]
# ### 1º Forma

# %%
# Función que divide en dos el poema, con cuidado que no divida por mitad de una palabra
# La primera mitad corresponde al input_encoder
# La segunda mitad corresponde al input_decoder
def split_text(text):
    # Calcula la longitud total del texto
    text_length = len(text)

    # Encuentra el índice medio del texto
    middle_index = text_length // 2

    # Retrocede desde el índice medio hasta el inicio del texto y encuentra el espacio más cercano
    start_index = text.rfind(' ', 0, middle_index)

    # Retrocede desde el índice medio hasta el final del texto y encuentra el espacio más cercano
    end_index = text.find(' ', middle_index)

    # Si no se encontraron espacios antes o después del índice medio, ajusta los índices para dividir entre palabras
    if start_index == -1:
        start_index = 0
    if end_index == -1:
        end_index = text_length

    # Divide el texto en dos partes
    first_half = text[:end_index]
    second_half = text[end_index:]

    return first_half, second_half

# %%
# Agrupamos por pares las dos mitades
# A la segunda mitad le añadimos [start] al principio
# y [end] al final
poema_pairs = []
for poema in poemas:
  poema_mitad1, poema_mitad2 = split_text(poema)
  poema_pairs.append((poema_mitad1, "[start]" + poema_mitad2 + " [end]"))

# %%
# Separar el conjunto en entrenamiento, validación y test
# 15% validación
num_val_samples = int(0.15 * len(poema_pairs))
# 70% entrenamiento
num_train_samples = len(poema_pairs) - 2 * num_val_samples
train_pairs = poema_pairs[:num_train_samples]
val_pairs = poema_pairs[num_train_samples:num_train_samples + num_val_samples]
# 15% test o pruebas
test_pairs = poema_pairs[num_train_samples + num_val_samples:]

# %%
# Prepara una función de estandarización de cadenas
# personalizada para la capa TextVectorization en
# español: conserva [ y ] pero elimina ¿ y ¡ (así como
# todos los demás caracteres de cadenas.puntuación)
# Poemas
strip_chars = string.punctuation + "¿" + "¡"
strip_chars = strip_chars.replace("\\", "")

# Poemas con [start] y [end]
strip_chars2 = string.punctuation + "¿" + "¡"
strip_chars2 = strip_chars2.replace("[", "")
strip_chars2 = strip_chars2.replace("]", "")
strip_chars2 = strip_chars2.replace("\\", "")

# Poemas
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars)}]", "")

text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length,
    standardize=custom_standardization,
)

# Poemas con [start] y [end]
def custom_standardization_2(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars2)}]", "")

text_vectorization_start_end = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    # Generamos poemas que tengan un token
    # adicional, ya que necesitaremos compensar la oración
    # en un paso durante el entrenamiento
    output_sequence_length=max_length + 1,
    standardize=custom_standardization_2,
)

train_poemas = [pair[0] for pair in train_pairs]
train_poemas_start_end = [pair[1] for pair in train_pairs]

# Aprende el vocabulario de los poemas
text_vectorization.adapt(train_poemas)
text_vectorization_start_end.adapt(train_poemas_start_end)

# %%
def format_dataset(p, p_s_e):
    p = text_vectorization(p)
    p_s_e = text_vectorization_start_end(p_s_e)
    return ({
        "poema": p,
        # El poema de entrada
        # no incluye el último token para
        # mantener las entradas y los
        # objetivos en la misma longitud.
        "poema_start_end": p_s_e[:, :-1],
    # El poema objetivo está un
    # paso por delante. Ambos siguen siendo
    # de la misma longitud
    }, p_s_e[:, 1:])

def make_dataset(pairs):
    poema_texts, poema_start_end_texts = zip(*pairs)
    poema_texts = list(poema_texts)
    poema_start_end_texts = list(poema_start_end_texts)
    dataset = tf.data.Dataset.from_tensor_slices((poema_texts, poema_start_end_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset, num_parallel_calls=4)
    # Utilizamos el almacenamiento en caché en memoria
    # para acelerar el preprocesamiento
    return dataset.shuffle(2048).prefetch(16).cache()

# Construimos los dataset en un tensor de 2 dimensiones (input, target)
# input a su vez se divide en input_encoder e input_decoder
# target es el poema al que el Transformer debería llegar
train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %%
# Observamos que esté todo en orden
for inputs, targets in train_ds.take(1):
  print(f"inputs['poema'].shape: {inputs['poema'].shape}")
  print(f"inputs['poema_start_end'].shape: {inputs['poema_start_end'].shape}")
  print(f"targets.shape: {targets.shape}")
# Out:
# inputs['poema'].shape: (4, 110)
# inputs['poema_start_end'].shape: (4, 110)
# targets.shape: (4, 110)

# %%
# Definimos el Encoder
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        # Tamaño de los vectores de los tokens de entrada
        self.embed_dim = embed_dim
        # Tamaño de la capa densa interna
        self.dense_dim = dense_dim
        # Número de attention heads
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    # El cálculo va en call()
    def call(self, inputs, mask=None):
        # La máscara que generará la capa Embedding
        # será 2D, pero la capa de atención espera
        # ser 3D o 4D, por lo que ampliamos su rango
        if mask is not None:
            mask = mask[:, tf.newaxis, :]
        attention_output = self.attention(
            inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    # Implementamos la serialización para
    # que podamos guardar el modelo
    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

# %%
# Definimos el Decoder
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        # Este atributo asegura que la capa propagará
        # su máscara de entrada a sus salidas; el
        # enmascaramiento en Keras es explícitamente
        # opt-in. Si pasa una máscara a una capa que
        # no implementa compute_mask() y que no expone
        # este atributo support_masking, es un error.
        self.supports_masking = True

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        else:
            padding_mask = mask
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %%
# Definimos el positional embedding
# A la capa embedding se le ha añadido el parámetro mask_zero = True
# Para que no tenga en cuenta los 0 generados por el zero padding
class PositionalEmbedding(layers.Layer):
    # Una desventaja de las incrustaciones de posición es que
    # la longitud de la secuencia debe conocerse de antemano
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        # Prepara una capa de embedding para los índices de token.
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim, mask_zero = True)
        self.position_embeddings = layers.Embedding(
            # Y otro para las posiciones te tokens
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        # Agrega ambos vectores embeddings juntos
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        # Al igual que la capa de embedding,
        # esta capa debería poder generar una
        # máscara para que podamos ignorar los
        # ceros de relleno en las entradas.
        # El framework llamará automáticamente
        # al método compute_mask y la máscara
        # se propagará a la siguiente capa.
        return tf.math.not_equal(inputs, 0)

    # Implementamos la serialización para que
    # podamos guardar el modelo.
    def get_config(self):
        config = super().get_config()
        # config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config

# %%
# Transformer encoder
encoder_inputs = keras.Input(shape=(None,), dtype="int64", name = "poema")
x = PositionalEmbedding(max_length, max_tokens, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, dense_dim, num_heads)(x)

# Transformer decoder
decoder_inputs = keras.Input(shape=(None,), dtype="int64", name = "poema_start_end")
x = PositionalEmbedding(max_length, max_tokens, embed_dim)(decoder_inputs)
# Codificamos la oración objetivo y la combinamos con la oración fuente codificada
x = TransformerDecoder(embed_dim, dense_dim, num_heads)(x, encoder_outputs)
x = layers.Dropout(0.5)(x)

# Predecimos una palabra para cada posición de salida
decoder_outputs = layers.Dense(max_tokens, activation="softmax")(x)
transformer = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

transformer.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
transformer.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  poema (InputLayer)          [(None, None)]               0         []
#
#  poema_start_end (InputLaye  [(None, None)]               0         []
#  r)
#
#  positional_embedding_2 (Po  (None, None, 256)            464640    ['poema[0][0]']
#  sitionalEmbedding)
#
#  positional_embedding_3 (Po  (None, None, 256)            464640    ['poema_start_end[0][0]']
#  sitionalEmbedding)
#
#  transformer_encoder (Trans  (None, None, 256)            543776    ['positional_embedding_2[0][0]
#  formerEncoder)                                                     ']
#
#  transformer_decoder_2 (Tra  (None, None, 256)            1070368   ['positional_embedding_3[0][0]
#  nsformerDecoder)                                                   ',
#                                                                      'transformer_encoder[0][0]']
#
#  dropout (Dropout)           (None, None, 256)            0         ['transformer_decoder_2[0][0]'
#                                                                     ]
#
#  dense_10 (Dense)            (None, None, 1705)           438185    ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2981609 (11.37 MB)
# Trainable params: 2981609 (11.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
transformer.fit(train_ds, epochs=EPOCHS, validation_data=val_ds)
# Out:
# Epoch 1/30
# 9/9 [==============================] - 8s 391ms/step - loss: 6.8699 - accuracy: 0.0356 - val_loss: 6.4203 - val_accuracy: 0.0455
# Epoch 2/30
# 9/9 [==============================] - 2s 243ms/step - loss: 6.1502 - accuracy: 0.0642 - val_loss: 6.3880 - val_accuracy: 0.0668
# Epoch 3/30
# 9/9 [==============================] - 2s 228ms/step - loss: 5.7382 - accuracy: 0.1033 - val_loss: 6.2978 - val_accuracy: 0.0775
# Epoch 4/30
# 9/9 [==============================] - 2s 205ms/step - loss: 5.2065 - accuracy: 0.1499 - val_loss: 6.2287 - val_accuracy: 0.0802
# Epoch 5/30
# 9/9 [==============================] - 3s 319ms/step - loss: 4.7243 - accuracy: 0.1890 - val_loss: 6.2460 - val_accuracy: 0.0722
# Epoch 6/30
# 9/9 [==============================] - 3s 306ms/step - loss: 4.2358 - accuracy: 0.2466 - val_loss: 6.2299 - val_accuracy: 0.0829
# Epoch 7/30
# 9/9 [==============================] - 3s 347ms/step - loss: 3.8159 - accuracy: 0.3043 - val_loss: 6.2427 - val_accuracy: 0.0775
# Epoch 8/30
# 9/9 [==============================] - 3s 310ms/step - loss: 3.3885 - accuracy: 0.3865 - val_loss: 6.2047 - val_accuracy: 0.0749
# Epoch 9/30
# 9/9 [==============================] - 3s 290ms/step - loss: 3.0072 - accuracy: 0.4642 - val_loss: 6.2717 - val_accuracy: 0.0695
# Epoch 10/30
# 9/9 [==============================] - 3s 378ms/step - loss: 2.6986 - accuracy: 0.5464 - val_loss: 6.3119 - val_accuracy: 0.0749
# Epoch 11/30
# 9/9 [==============================] - 2s 210ms/step - loss: 2.3620 - accuracy: 0.6050 - val_loss: 6.4051 - val_accuracy: 0.0695
# Epoch 12/30
# 9/9 [==============================] - 2s 204ms/step - loss: 2.0954 - accuracy: 0.6541 - val_loss: 6.4151 - val_accuracy: 0.0615
# Epoch 13/30
# 9/9 [==============================] - 2s 221ms/step - loss: 1.8745 - accuracy: 0.7048 - val_loss: 6.5287 - val_accuracy: 0.0668
# Epoch 14/30
# 9/9 [==============================] - 2s 204ms/step - loss: 1.6647 - accuracy: 0.7168 - val_loss: 6.4737 - val_accuracy: 0.0749
# Epoch 15/30
# 9/9 [==============================] - 3s 367ms/step - loss: 1.4469 - accuracy: 0.7609 - val_loss: 6.5969 - val_accuracy: 0.0561
# Epoch 16/30
# 9/9 [==============================] - 2s 213ms/step - loss: 1.2984 - accuracy: 0.8000 - val_loss: 6.5951 - val_accuracy: 0.0722
# Epoch 17/30
# 9/9 [==============================] - 2s 214ms/step - loss: 1.1452 - accuracy: 0.8145 - val_loss: 6.7531 - val_accuracy: 0.0615
# Epoch 18/30
# 9/9 [==============================] - 2s 219ms/step - loss: 1.0214 - accuracy: 0.8441 - val_loss: 6.7008 - val_accuracy: 0.0642
# Epoch 19/30
# 9/9 [==============================] - 2s 269ms/step - loss: 0.9121 - accuracy: 0.8617 - val_loss: 6.7993 - val_accuracy: 0.0695
# Epoch 20/30
# 9/9 [==============================] - 3s 368ms/step - loss: 0.7860 - accuracy: 0.8857 - val_loss: 6.8457 - val_accuracy: 0.0642
# Epoch 21/30
# 9/9 [==============================] - 2s 208ms/step - loss: 0.7274 - accuracy: 0.9033 - val_loss: 6.9354 - val_accuracy: 0.0588
# Epoch 22/30
# 9/9 [==============================] - 2s 212ms/step - loss: 0.6259 - accuracy: 0.9148 - val_loss: 6.9432 - val_accuracy: 0.0722
# Epoch 23/30
# 9/9 [==============================] - 2s 247ms/step - loss: 0.5404 - accuracy: 0.9323 - val_loss: 7.0528 - val_accuracy: 0.0615
# Epoch 24/30
# 9/9 [==============================] - 2s 223ms/step - loss: 0.4617 - accuracy: 0.9444 - val_loss: 7.0652 - val_accuracy: 0.0615
# Epoch 25/30
# 9/9 [==============================] - 3s 313ms/step - loss: 0.4276 - accuracy: 0.9474 - val_loss: 7.0822 - val_accuracy: 0.0722
# Epoch 26/30
# 9/9 [==============================] - 2s 243ms/step - loss: 0.3626 - accuracy: 0.9644 - val_loss: 7.1617 - val_accuracy: 0.0642
# Epoch 27/30
# 9/9 [==============================] - 2s 215ms/step - loss: 0.3222 - accuracy: 0.9644 - val_loss: 7.2537 - val_accuracy: 0.0561
# Epoch 28/30
# 9/9 [==============================] - 2s 213ms/step - loss: 0.2934 - accuracy: 0.9649 - val_loss: 7.3171 - val_accuracy: 0.0615
# Epoch 29/30
# 9/9 [==============================] - 3s 347ms/step - loss: 0.2552 - accuracy: 0.9769 - val_loss: 7.3420 - val_accuracy: 0.0508
# Epoch 30/30
# 9/9 [==============================] - 2s 216ms/step - loss: 0.2068 - accuracy: 0.9835 - val_loss: 7.4180 - val_accuracy: 0.0588

# %%
# Vamos a probar que tal genera poemas nuestro modelo
poema_vocab = text_vectorization_start_end.get_vocabulary()
spa_index_lookup = dict(zip(range(len(poema_vocab)), poema_vocab))
max_decoded_sentence_length = max_length

def decode_sequence(input_sentence):
    tokenized_input_sentence = text_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = text_vectorization_start_end(
            [decoded_sentence])[:, :-1]
        predictions = transformer(
            [tokenized_input_sentence, tokenized_target_sentence])
        # Muestra el siguiente token
        sampled_token_index = np.argmax(predictions[0, i, :])
        # Convertimos la siguiente predicción del token en una
        # cadena y la agregamos a la oración generada
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token
        # Condición de salida
        if sampled_token == "[end]":
            break
    return decoded_sentence

test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(5):
    input_sentence = random.choice(test_eng_texts)
    print("-")
    print(input_sentence)
    print(decode_sequence(input_sentence))
# Out:
# -
# Hoy, en mitad de la vida,
#  me he parado a meditar...
#  ¡Juventud nunca vivida
#  quién te volviera a soñar!
#  Eran ayer mis dolores
#  como gusanos de seda
#  que iban labrando capullos;
#  hoy son mariposas negras.
#  ¡De cuántas flores amargas
#  ha sacado blanca cera!
#  ¡Oh tiempo en que
# [start] no sé qué triste es tu suerte medrosas tiritan tus hojas de la primavera tú has dicho el secreto que en mi alma cuando bosteza el viento agita el llanto es una voz o un eco para escuchar tu queja de la clase en la una [end]
# -
# que llegaron al alma, al hondo cielo?
#  ¿Y ha de morir contigo el mundo tuyo,
#  la vieja vida en orden tuyo y nuevo?
#  ¿Los yunques y crisoles de tu alma
#  trabajan para el polvo y para el viento?
#  Desnuda está la tierra,
#  y el alma aúlla al horizonte pálido
#  como loba famélica. ¿Qué buscas,
#  poeta, en el ocaso?
#  Amargo caminar, porque el camino
# [start] maduro o florido de frondas y aromas y espuma ríen los zumos de la plaza muerta— viene a encender las rosas rojas de un día a nuestra casa llega nosotros le decimos por qué tornas a la morada vieja ella abre la buena albahaca que tenía mi madre en sus macetas que tú me viste hundir mis manos puras en el agua serena [end]
# -
# mañana petenera,
#  según quien llega y tañe
#  las empolvadas cuerdas,
#  guitarra del mesón de los caminos,
#  no fuiste nunca, ni serás, poeta.
#  Tú eres alma que dice su armonía
#  solitaria a las almas pasajeras...
#  Y siempre que te escucha el caminante
#  sueña escuchar un aire de su tierra.
#  La primavera
# [start] se pinta y la monotonía de agua clara el cántaro llenas mientras la primavera tú has dicho el secreto que en mi alma cuando bosteza el viento agita el corazón clavada amada el aura dice tu pura veste blanca no te verán mis ojos [end]
# -
# que arranca el limo a la tierra.
#  Dolores que ayer hicieron
#  de mi corazón colmena,
#  hoy tratan mi corazón
#  como a una muralla vieja:
#  quieren derribarlo, y pronto,
#  al golpe de la piqueta.
#  Húmedo está, bajo el laurel, el banco
#  de verdinosa piedra;
#  lavó la lluvia, sobre el muro blanco,
#  las empolvadas hojas de la hiedra.
#  Del viento del otoño
# [start] maduro o florido de la más allá la alegre canción de un alba de la eterna rueda la dulce armonía del agua que un día a nuestra casa llega nosotros le decimos por qué tornas a la morada vieja ella abre la buena albahaca que muere hay ecos de la luz de los cabellos que él en sus madrigales llamaba rubias olas brotó porque un aroma igual tuvieron ellos y se alejó en silencio para llorar a solas [end]
# -
# que arranca el limo a la tierra.
#  Dolores que ayer hicieron
#  de mi corazón colmena,
#  hoy tratan mi corazón
#  como a una muralla vieja:
#  quieren derribarlo, y pronto,
#  al golpe de la piqueta.
#  Húmedo está, bajo el laurel, el banco
#  de verdinosa piedra;
#  lavó la lluvia, sobre el muro blanco,
#  las empolvadas hojas de la hiedra.
#  Del viento del otoño
# [start] maduro o florido de la más allá la alegre canción de un alba de la eterna rueda la dulce armonía del agua que un día a nuestra casa llega nosotros le decimos por qué tornas a la morada vieja ella abre la buena albahaca que muere hay ecos de la luz de los cabellos que él en sus madrigales llamaba rubias olas brotó porque un aroma igual tuvieron ellos y se alejó en silencio para llorar a solas [end]

# %% [markdown]
# ### 2ª Forma

# %% [markdown]
# Tal y como se observa en las generaciones anteriores, se repiten las palabras en muchos de ello. Para evitar esto, se debe de otorgar algo de creatividad al modelo, para ello hay que meter cierta aleatoriedad a la hora de asignar cual va a ser la siguiente palabra.
#
# En este modelo de IA generativa, solo tenemos un dataset, los poemas, no es necesario dividir estos en train, val y test.

# %% [markdown]
# Por ello, el primer paso es generar el dataset a partir del array de los poemas.

# %%
def make_dataset(poemas):
    poemas = list(poemas)
    dataset = tf.data.Dataset.from_tensor_slices(poemas)
    dataset = dataset.batch(batch_size)
    # Utilizamos el almacenamiento en caché en memoria
    # para acelerar el preprocesamiento
    return dataset.shuffle(2048).prefetch(16).cache()

# Construimos los dataset en un tensor de 2 dimensiones (input, target)
# input a su vez se divide en input_encoder e input_decoder
# target es el poema al que el Transformer debería llegar
poemas_ds = make_dataset(poemas)

# %%
strip_chars = string.punctuation + "¿" + "¡"
strip_chars = strip_chars.replace("\\", "")

# Poemas
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(
        lowercase, f"[{re.escape(strip_chars)}]", "")

# Creamos la vectorización
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    # Queremos devolver secuencias de índice
    # de palabras con valores enteros
    output_mode="int",
    output_sequence_length=max_length,
    standardize=custom_standardization,
)

text_vectorization.adapt(poemas_ds)

# %%
def prepare_lm_dataset(poemas):
    # Convertimos un lote de textos (cadenas)
    # en un lote de secuencias enteras.
    vectorized_sequences = text_vectorization(poemas)
    # Creamos entradas cortando la última palabra de las secuencias
    x = vectorized_sequences[:, :-1]
    # Creamos objetivos compensando las secuencias por 1.
    y = vectorized_sequences[:, 1:]
    return x, y

poemas_ds = poemas_ds.map(prepare_lm_dataset, num_parallel_calls=4)

# %%
# Definimos el Decoder
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        # Este atributo asegura que la capa propagará
        # su máscara de entrada a sus salidas; el
        # enmascaramiento en Keras es explícitamente
        # opt-in. Si pasa una máscara a una capa que
        # no implementa compute_mask() y que no expone
        # este atributo support_masking, es un error.
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        else:
            padding_mask = mask
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %%
# Definimos el positional embedding
# A la capa embedding se le ha añadido el parámetro mask_zero = True
# Para que no tenga en cuenta los 0 generados por el zero padding
class PositionalEmbedding(layers.Layer):
    # Una desventaja de las incrustaciones de posición es que
    # la longitud de la secuencia debe conocerse de antemano
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        # Prepara una capa de embedding para los índices de token.
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim, mask_zero = True)
        self.position_embeddings = layers.Embedding(
            # Y otro para las posiciones te tokens
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        # Agrega ambos vectores embeddings juntos
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        # Al igual que la capa de embedding,
        # esta capa debería poder generar una
        # máscara para que podamos ignorar los
        # ceros de relleno en las entradas.
        # El framework llamará automáticamente
        # al método compute_mask y la máscara
        # se propagará a la siguiente capa.
        return tf.math.not_equal(inputs, 0)

    # Implementamos la serialización para que
    # podamos guardar el modelo.
    def get_config(self):
        # config = super().get_config()
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config

# %%
# Transformer decoder
decoder_inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(max_length, max_tokens, embed_dim)(decoder_inputs)
# Codificamos la oración objetivo y la combinamos con la oración fuente codificada
x = TransformerDecoder(embed_dim, dense_dim, num_heads)(x, x)

# Predecimos una palabra para cada posición de salida
decoder_outputs = layers.Dense(max_tokens, activation="softmax")(x)
model = keras.Model(decoder_inputs, decoder_outputs)

model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy")
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, None)]               0         []
#
#  positional_embedding_6 (Po  (None, None, 256)            454912    ['input_5[0][0]']
#  sitionalEmbedding)
#
#  transformer_decoder_5 (Tra  (None, None, 256)            1070368   ['positional_embedding_6[0][0]
#  nsformerDecoder)                                                   ',
#                                                                      'positional_embedding_6[0][0]
#                                                                     ']
#
#  dense_19 (Dense)            (None, None, 1667)           428419    ['transformer_decoder_5[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 1953699 (7.45 MB)
# Trainable params: 1953699 (7.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Dict (diccionario) que asigna o mapea índices de palabras
# a cadenas, para usarlos para decodificar texto
tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

# Implementa el muestreo de variable-temperatura
# a partir de una distribución de probabilidad
def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self,
                 # Indicación o prompt que usamos para
                 # iniciar la generación de texto
                 prompt,
                 # Cuantas palabras generar
                 generate_length,
                 model_input_length,
                 # Rango de temperaturas
                 # a usar para el muestreo
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq
        vectorized_prompt = text_vectorization([prompt])[0].numpy()
        self.prompt_length = np.nonzero(vectorized_prompt == 0)[0][0]

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            # Al generar texto, comenzamos
            # desde nuestro prompt o aviso.
            sentence = self.prompt
            for i in range(self.generate_length):
                # Alimentamos nuestro modelo con la secuencia actual
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                # Recuperamos las predicciones del último timestep y las
                # utilizamos para muestrear o probar una nueva palabra.
                next_token = sample_next(
                    # O [0, i, :]
                    predictions[0, self.prompt_length - 1 + i, :]
                )
                sampled_token = tokens_index[next_token]
                # Agregamos la nueva palabra a
                # la secuencia actual y repetimos
                sentence += " " + sampled_token
            print(sentence)

prompt = "En el mar"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=max_length,
    # Usaremos un rango diverso de
    # temperaturas para muestrear texto,
    # para demostrar el efecto de la
    # temperatura en la generación de texto.
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %%
model.fit(poemas_ds, epochs=20, callbacks=[text_gen_callback])
# Out:
# Epoch 1/20
# 13/13 [==============================] - ETA: 0s - loss: 5.3070== Generating with temperature 0.2
# En el mar aire las —juguetes ya llanto quisiera a la emerge penetró duerme ancho gloria agua pierde nubes almas el viejo humo detén mal nuevo que de la sala laguna alma lo desde puros lágrimas de bien serpea que en solitaria con dista canción galerías la hastío la —contigo aceros humilde y
# == Generating with temperature 0.5
# En el mar tú de agudas mañana un empecé clara el maduro aura los pena todavía verán nunca nube y mundo el de al alcanzar de hondas la cipresal hacen las tictac cuando el lienzos mar rincón llamar blancas aire obscurece o casi corría primavera caminos letra  vidrio en sol de en
# == Generating with temperature 0.7
# En el mar míos los naranjo quieren aleja lo reflejo ella  ha dentro algún de luna los muda y dos querido humareda seco recuerdo los música que que el rubia amplia corazón salir viento carne el casi el ha los he se soberbios  conozco y hilo ser y irá los tus
# == Generating with temperature 1.0
# En el mar el áspera viento tormenta de amada el en deshójanse remoto serio sonreía truena el zumo compás rostro en tenían tierra verdadero las —eres monedita el honda aguardan fuerte mi doncellita de toda es ligera sombría cristalina cegado el caía rojas fantasmas mismo al todo pompa de y beben caminando mejor
# == Generating with temperature 1.5
# En el mar dista te viejas al desorden cristalino cuerdas altos fantasmas todas juegan muere exprimimos flor bajo el llanto clarea el campo mañana dar de piensan plaza enciende poeta sombrío al de criptas soñaba— querías oro alegre y las sube seco alegre húmedo las girando sombra ni lo trajo le como buscando
# 13/13 [==============================] - 17s 1s/step - loss: 5.3070
# Epoch 2/20
# 13/13 [==============================] - ETA: 0s - loss: 4.6480== Generating with temperature 0.2
# En el mar sangre el sombrío dice guarda el hastío es trémula nardo ancho y moneda verano mis resol morir huertos las torreón soñaba— antes labrando ni un arrugadas nuestras oh marchito corazón acordaba de desde cierran soñando el encantado golpear tierra siempre viajero polvo cristales a la traes contigo camina afiladas la
# == Generating with temperature 0.5
# En el mar y quedó con julio a quién latía guarda cielo disperso llano las pobre momento que en el — casi de claro tu … la enfrente ciega vidrieras aguda levantará prado aturde de palpita pulido algún su y dices pesa la amado que perdida oh peluquero de amarillo florida viril oro
# == Generating with temperature 0.7
# En el mar en el viento versos huyendo entre los lamentará os naranjo os de gentiles sombras  tenue no desde el algunos la cristal —recordé— confusa aun árboles pero en viejas eran la con acuerdas de la hecho porque caer mudo los reposa atónito julio calaveras mirarte y ese aguas iba y
# == Generating with temperature 1.0
# En el mar aire para hierve y coro está surca dolor rostros enhiestas recuerdos golpe vais caminos apaga como agua es del lejanía jardín el del mustios escuchar cursilerías sonoras vagar santa leyenda ve que como ancho el sol en quizás vertía enturbia un madre cristales de abril dorado encanto tumbas se despierto
# == Generating with temperature 1.5
# En el mar gentiles su pasaron brusca de frondas los árboles de ese y fuente porque entreabierto arrugadas nueva Él repercutir ese los frutos de zumos rosas escuela un todas aromas y beben el tictac al silencioso se verdinosa aromas quieta fría parque el azul blancas caja blanco la llega y era la
# 13/13 [==============================] - 16s 1s/step - loss: 4.6480
# Epoch 3/20
# 13/13 [==============================] - ETA: 0s - loss: 4.0064== Generating with temperature 0.2
# En el mar en buscas que en los nuestras redondas hoy alba abate disperso en mundo en en el corazón mística los a las espina de lluvia —no lágrimas y tu demonio a la mágicos las espejo de amores algunos aquel vagar el —a no sé ya tarde encantados que se mirra sueñan
# == Generating with temperature 0.5
# En el mar el sopor y sé  tu los la limpia irá florido mitad nunca la alma el sólo y y de verán oh de yo de de y todo no pobre sombra traerte bosque de la y de que florido nuestras purpurinas morir mundo y hermosa lágrimas dulce y piedra cuarto
# == Generating with temperature 0.7
# En el mar amor doradas del vaso tu con un un negra mano del y el aire de traído tus enmaraña tras el ocaso silencio sombra sobre la tarde blanca suspirar parece la canciones tras los teoría cristalino compás el misterioso el viento el viento el labios en el azul paso juncal al
# == Generating with temperature 1.0
# En el mar de tus clarea del todo exhalarán en el quimera cargado de que el sol en el iglesia ya doncellita que fuente barren que de la tarde traje que afiladas y órgano mira de la se fríamente mil da momento en maceta qué sombríos de sombra de las tabernas tarde en
# == Generating with temperature 1.5
# En el mar cien y quemar triste volver huir una miradas en la fuente quimérica soñado cantaban los alegría juvenil salterios los cangilones el fondo por recortados y cuentos de la mortecinos perfuman su tierra de cobre empecé razón de lo la hadas cangilones que soledad tarde la mano montes ronco que era
# 13/13 [==============================] - 17s 1s/step - loss: 4.0064
# Epoch 4/20
# 13/13 [==============================] - ETA: 0s - loss: 3.4337== Generating with temperature 0.2
# En el mar clase en blanca surca de la saben crear vacíos duerme dos dime aquellos añora verano abril santas que qué detén el cayendo daba el jardín vida adonde el truena el pisados la mano que risueñas enciende la serás  reposa tú aquel de frente de pasa áspera a albo quimérica
# == Generating with temperature 0.5
# En el mar campanario arranca en aguardas tu halago fuente de viejo— deba mi copia con derruida al vidas finos pesados llama arruinada cortas las rodar mi corazón tu quedó colmena fragancias plateadas voz nunca llega dijo la angosta frente aturde que en apartaré daguerrotipos hálitos ya que lo la fuente de risa
# == Generating with temperature 0.7
# En el mar sé invierno las apagaron casco pesadilla los risueño feroz volar miradas en la hogar hacia caía del feroz la esperanzas sombra el hada alumbras del visto blanco el en la lloras era que que iglesia redondas y pequeños piedra río que nunca gente niebla mira guardan temblando sala las músicas
# == Generating with temperature 1.0
# En el mar de inquietud de gentiles huyendo unió pena hoy martillo tristeza la entreabierta dónde leyenda beben dices iglesia efunde  preguntan arrancármela ventiscas viajero acacia altar de quietas azul suena oh y gran divagamos flor amplio callejas muere ojos gentiles enturbia con esquelética que flor flor undula lluvia pasos vida mañana
# == Generating with temperature 1.5
# En el mar de reír la tormenta iglesia lado el mármol juventud halago  que que hermano de el derruida campanas  tú te amarillean las el el era nuevas nuestras algún que fuera de palpitar mundo secreto y del vuestros no sueña morir sangre amores viejo— alguna hada espiga huecas el con
# 13/13 [==============================] - 23s 2s/step - loss: 3.4337
# Epoch 5/20
# 13/13 [==============================] - ETA: 0s - loss: 2.9328== Generating with temperature 0.2
# En el mar he dijo un espino celeste que al equívoco de la respondió poeta risa de más amplia de yo encontrada suave flor la nuevos un inquietud de la semblante santas dijo la contigo otros sé la hora campo universal humedad una colmena cristal ventiscas la llano aguardan las tutelar rezo hoy
# == Generating with temperature 0.5
# En el mar inhospitalario los cadenas y sabes que el truena el cielo primavera rosas el agua en el campo un abuela de la siempre cesa de viejo— aún caer la a su las hojas de la noche el luz en el ruido infinito en el nosotros inciensos humilde en sombra de la
# == Generating with temperature 0.7
# En el mar se brilla la tarde en el su nevascas y más luz el llano la más corazón y dorado y al huecos transparente armonía el golpe de una a la verdinosa vierten en el secreto que agita el encanto tictac luz la eucalipto del muchos ha marmórea halago primavera se estrellas
# == Generating with temperature 1.0
# En el mar que al adónde campo paso campo el camino blande el quizá sobre la iglesia al pasos vas muchos con el sangriento gusanos de la blanca tus todos la paz en el viento el corazón te burlón aroma coro y del sueño fingía el agua de tu pura limpio que pesadilla
# == Generating with temperature 1.5
# En el mar y al trabajaban sueño sentir en una tarde de flor en las frescas viejas plácida y bajo el sueño en la música y son alegres de la tarde retrato en un cristalino estepa y dónde están los en toda duelo daguerrotipo viejo enmaraña blancas la saben alguna llevarán y huecas
# 13/13 [==============================] - 22s 2s/step - loss: 2.9328
# Epoch 6/20
# 13/13 [==============================] - ETA: 0s - loss: 2.5071== Generating with temperature 0.2
# En el mar y lleváronse amiga y serio huerto hoy dista sentí el una rama suave de azogue extinguen sopor silba burlón sombra del camino azul o derruida calienta mías y inerte responden a un peluquero recuerdo tarde más que amarillean limonero que el aire de buenas y el alma pulido pálido una
# == Generating with temperature 0.5
# En el mar marchita y todavía pesar del esquiva viste árboles de oro  ausencia viejo blanca flor de oro la y y en oro de yunques cuando atril donde muere nuestro y de torna pobre oh la yo —contigo cambio siempre tronchada cangilones algo oh al si muro aun arrumbados soñando la
# == Generating with temperature 0.7
# En el mar ni vuestros luego de jabón quieren mío navegado en el madurarán y tras la pavor pequeños colegiales magas de has galerías doce y compás de tu morir contigo es una señas con una mañana por la hondas fantasma cierto blancas partir hacia un besar quisiera vellón mí la luna desgarrada
# == Generating with temperature 1.0
# En el mar el viento el redondas y blanco el piensan al corazón mientras soñaba— se rezar azul el sueño en la tarde en el sitio flor el oriente estrella — llano la polvo y bajo el viento largo del ancho tenían han llevas tú en dicho triste un sube lumbre de valle
# == Generating with temperature 1.5
# En el mar se ligera en mañana en tierra y al horizonte cera pretil de la dicho el huerto de poquito las puros de sombra del todo el va leídos que dice los detén el hada de la fuente de cuántas mal del ese roído y cigüeña parque mustio y cubierto el camino
# 13/13 [==============================] - 16s 1s/step - loss: 2.5071
# Epoch 7/20
# 13/13 [==============================] - ETA: 0s - loss: 2.1362== Generating with temperature 0.2
# En el mar tantos— vais sombras gentiles huyendo entre los árboles de oro  corazón te hoy traje nunca ciencia negra músicas almas si fiestas suspirar rosas aun es labrando y huerta piqueta se los viejo al otros todo está el razón tejado mal por encantado muralla dar golpes su de parece la
# == Generating with temperature 0.5
# En el mar clara soledad la qué fabrica su poeta en la ven y campo la torre y las alcoba buscando las ventanas sombra días sus árboles por la si montaña la monedita del ciprés del alma trabajan en las silenciosas sí te verán y encinas adonde un fresca como se alba agudas
# == Generating with temperature 0.7
# En el mar de la hierba la irrisorio caminos de las cada cera sombra y risueñas tumulto de tu alma tu dos pasaron —y tú niños sobre que en moneda que bajo la mano en los tortuosas la austero las estrellas levantará la tierra escalas dormirás julio bajo las misterioso pétalos y la
# == Generating with temperature 1.0
# En el mar alegre y conservamos y en mi sueño ni tenía la iglesia con musgo y sonríen —juguetes cayendo está— en mi tierra inhospitalario siento el tronco sopor del eran como algo sombría pasó por la largamente tarde de triste estrellas retablos cabeza y en su alameda hoy mis hastío oh mío
# == Generating with temperature 1.5
# En el mar el ocaso alondras en flor y los tañe las muerta— alma timbre a patio silencioso se pesa y está hiedra los hada de un eucalipto aromado verme cantos y la fuente de fiesta penumbra pronto será lo undula y truena el encanto arboleda montaña vieja negro la azada en viento
# 13/13 [==============================] - 22s 2s/step - loss: 2.1362
# Epoch 8/20
# 13/13 [==============================] - ETA: 0s - loss: 1.8445== Generating with temperature 0.2
# En el mar el sol la ayer copiaban el corazón sombrío donde el supe una —su patio carcomido inciensos de viento cabellos y sonríen quimera que no querías armonía del primavera van a daguerrotipo llorar de y efunde sobre el balcón teme olor sierra tutelar latía solo en el viento lirios juegan y
# == Generating with temperature 0.5
# En el mar hierve y duele el huyendo entre los árboles de oro  de   al secas moneda sube gentes lejos brotaba sabes de es  de nubes juventud miras habitaba ciento monotonía ilumina ponía de vimos cristal  surca siempre revelaste y plazoletas caminan que borrachos tocados moneda ocaso guardan
# == Generating with temperature 0.7
# En el mar de morirse de la tarde declinado soledad y arranca el viento su quien canción en cuyos bruma del arena la ceniza al siente la tarde se mas busca en la quiso el semblante en plegarias húmedo lluvia mira puros de sombra del alma que evoca en el laurel el vida
# == Generating with temperature 1.0
# En el mar de santa de la cabeza y cercano cabalgan a siempre días pero la luna muy blanca lienzos del alma cuando es una tarde blanco golondrinas se siento el viento yo todo el agua que mis espina de la tierra y vuelve buscas temas tú alejó esqueleto de la blanca te
# == Generating with temperature 1.5
# En el mar el pretil de la sonreído al cielo azul el viento el atril pomo revelaste ha hiedra eres alma mía paz en espiga —tal que nuestro de exhalarán me estéril la arena la buena afiladas y está fuego otra hermoso guitarra los colegiales barren los rincones de la palmeras y era
# 13/13 [==============================] - 17s 1s/step - loss: 1.8445
# Epoch 9/20
# 13/13 [==============================] - ETA: 0s - loss: 1.5965== Generating with temperature 0.2
# En el mar cercano aroma de llegar cantos y labráis burlón lentamente los tierra sobre como penetró el universal eran como como un titerero en surtidor de un perfume los muros sonar iglesia en la luz en la estancia limonero de fantasma por la noche la casa la tierra ocaso son era el
# == Generating with temperature 0.5
# En el mar el sol igual una desnuda está juvenil el sol el mar el sueño en el mar joven loba— muerta mi sueño dentro mi pobre rubias olas blanquecinos y pasados perfectamente ángel más vieja familiar el hada vez sus mes de mi corazón maduro o conozco tarde cantan quemar voltean suavemente
# == Generating with temperature 0.7
# En el mar y al oído por la llanura y vendó menguadas largo marchita campo dos todos los lamentará la tapia blanquecina de la sombra sombra negra al corazón duerme ruinosa iglesia en el santas mi agua clara luz ingenuas de te aguarda el viento en flor ha muchos y este amor te
# == Generating with temperature 1.0
# En el mar hierve y ese primavera inciensos de lento de irá horror alma contigo se ser camina en que fue un llorosas seco que en la ilumina carcoma en viento soñoliento blancas sombras en nuestro es la rosa hastío y pasando brilla una tarde en golpes del camino falucho mes agua clara
# == Generating with temperature 1.5
# En el mar y pedantones al morir tú has ha piedra con olas entre los apagaron pobre jardín hoy poetas nosotros perfectamente partir cielo y soñoliento casi amor como un día mañanas como dices rama rueca el alma cuando su colmenares pobre acaso desengaños qué joven naranjitas secas y la mar resol encajes
# 13/13 [==============================] - 17s 1s/step - loss: 1.5965
# Epoch 10/20
# 13/13 [==============================] - ETA: 0s - loss: 1.3889== Generating with temperature 0.2
# En el mar porque en la quisiera cesa de la serena —vendrás cárdenos camina y eran blanca niebla de las rostro del copia con verdoso del espejo el hada de la ayer es un encinas como suavemente la angosta frente llega y hermoso brillaban como mía pasar plañir escuchar españa solas voces te
# == Generating with temperature 0.5
# En el mar calcinó dormido colmenares de momento que ven y duerme y surtidor de las alas agudas al hender el los álamos de la cabeza y este aroma historia las ciudades menguadas cristal que llamas que quimeras rosadas que sueña muchos noche odio oro vuelta Él ha sonreído al rama nosotros exprimimos
# == Generating with temperature 0.7
# En el mar hierve y polvorienta y las colinas enturbie buscas poeta tú era fuego a una pasión según cortas las verte con sus miradas dalias malhaya tu jardín hoy son óvalo tus rosas aromado aguda negra caja y azul espiga como siempre cauce palmos de los corte qué pena vino agua clara
# == Generating with temperature 1.0
# En el mar cuando su sombría y los rincones de los labio la blanca vela henchida Él ha visto la verde lágrimas triste falucho penetró si el pálido como encontrada tus linda crespón del río la tristeza se meditando suena el viento al aire del reloj otoño el viento huyó mi pobre voz
# == Generating with temperature 1.5
# En el mar hierve y algo que tú las hojas de la el corazón pasión canciones vidas vida su tonel el mundo en sueños geranios de días aun lejanos figurillas sutiles que los crudos soplos de la copas conservamos fresco las salas polvorientas grave abuela el tuyo y era las golondrinas se canta
# 13/13 [==============================] - 17s 1s/step - loss: 1.3889
# Epoch 11/20
# 13/13 [==============================] - ETA: 0s - loss: 1.2127== Generating with temperature 0.2
# En el mar estoica cerca de la grave sueño por una fuente mucho de solitaria a fuente noria lenta soñaba mi corazón una fragancia y frutos pura verdes tenue voz que borra el álamos de mis ojos mi triste su conseja de otros días mustios encajes y pálido lienzo de tejado la pobre
# == Generating with temperature 0.5
# En el mar famélica qué buscas poeta galante mirra y este platea en flor en sombra blanca esa pobre fronda marchita como en la maceta qué frente y volando y las vidrieras con pasajeras y los hierbas donde yo voy caminando por la tarde hierbas alguna humilde flor en sombra lloras de la
# == Generating with temperature 0.7
# En el mar hierve y sé viejas cadencias que en flor pájaro escondido entre y sueño en las orillas del dorado y nuevo seco que han sonoro bajo doncellita que nunca supe adamantino respondí a soñar del reloj arrinconado que hacen camino blanco hace del sus laboran ha muda mis sueños y solitario
# == Generating with temperature 1.0
# En el mar encantado la sombra del patio querido hermano se pálidos porque en las empolvadas hojas ojos sobre ingrave en las golondrinas chillan pasaron del amor nevascas y soñando y algo chillan cipresal austero las voces de una acaba de la lleva un cartel se pierde erguidas en la loba famélica qué
# == Generating with temperature 1.5
# En el mar tutelar la sola y en sombra un canción de oro  hombro adónde mañanas tus tutelar secas manrique las como pálidos sombra y blanco como vertiendo y tibia amiga lluvias traje y mal y —como las silenciosas caminante mustios colmena querida y fuerte inopia lleva golpea mi aleja dentro
# 13/13 [==============================] - 22s 2s/step - loss: 1.2127
# Epoch 12/20
# 13/13 [==============================] - ETA: 0s - loss: 1.0715== Generating with temperature 0.2
# En el mar sonrió la vida me he parado el laguna el hada de lástima dos cuando en el viento no quién —recordé— yo meditaba reflejos monótono un ancho río que platea en las aquellos hora de mula vieja plaza sombría voces de los lentamente los ecos del camino la amargura de la
# == Generating with temperature 0.5
# En el mar alondras en el verde tú que soledad las quietas estoy solo en caminos no conocido tiempo en la ser camina en una forma tierra y palmeras y corazón y las sombrías torres repican las sería orillas del jabón al aire de la fuente sueñan cual vierten sus aguas las fuentes
# == Generating with temperature 0.7
# En el mar y al viento en la tarde flor en el piensan que el camino tu puerta vi en el sol de montes atrio hay que vida yerto y todo en suave de la casa y días ponía contigo el banco de hipocresía en el puro como rosado el naranjito en la
# == Generating with temperature 1.0
# En el mar te mí la estrella como clara una huerta hoy dónde tu saben henchida Él pasan las músicas magas de —dime ruinosa iglesia guardar sobre el palmeras y sólo el sueño en el buen que enseñan triste río ama tu iris el hada más hermosa ha sonreído al ver la lumbre
# == Generating with temperature 1.5
# En el mar hierve y luz la toro corazón maduro o fuente de una voz caminos no fuiste nunca ni serás está el tonel el azul monótono un ancho y fría llevan  se en puede y cantando está al hojas desolado tristezas fugitiva silencioso blanca que los cantaba más erguidas orillas tus
# 13/13 [==============================] - 20s 2s/step - loss: 1.0715
# Epoch 13/20
# 13/13 [==============================] - ETA: 0s - loss: 0.9414== Generating with temperature 0.2
# En el mar de la saeta las golondrinas linda doncellita que el iris brillando ya en tu virgen belleza del morir contigo el silencio un alba frente y lejanos figurillas sutiles que el de la vela celeste bajo el río memoria se alejan volando y escucha el cómo pasan las blancos otro día
# == Generating with temperature 0.5
# En el mar hierve y las quietas quema en el palmerilla sombrío meditando suena dos ramas del alma vieja al sol el aire está la dorada buscando una tarde en el alma y ríe en el traes el sangrientas llamas hojas amarillas y fosa los mazurca olvidada entre inocente y sol la su
# == Generating with temperature 0.7
# En el mar rutilante y manos dormido y en el querido hermano que tristeza si aguardas la alameda recordando vida vacías nuestras entre fieras fiestas de seda que rueda la desperté repite la sombría morada vieja negra caja y polvorienta yo madera la carretera y siempre cerca de oro más toda la blanca
# == Generating with temperature 1.0
# En el mar tras amores de dormido y clara el agua de hasta está el sueño lamentará la sombra calavera ya sonreír todas rodar las recuerdos figurillas que va apestando la mano morena ni luego en el viento solitario y ama tu tristeza si buscas caminos en suspirar de la pasados los escucha
# == Generating with temperature 1.5
# En el mar arrojando el paso equívoco añora y dorado qué lumbre de la espina dorada la tarde alegre y temblorosa mis dolores que el cristal vuestros mirra y dista algún recuerdo los álamos de un alba de cristal te contemplas tú ese estrofa de lluvia sobre el camino que silencio desgarrada la
# 13/13 [==============================] - 21s 2s/step - loss: 0.9414
# Epoch 14/20
# 13/13 [==============================] - ETA: 0s - loss: 0.8231== Generating with temperature 0.2
# En el mar hierve y de tu copa tictac soledad tu quieta espuma del amor pensamos volviera a la bendita soledad tu barca a hadas risueña se deba guardar la monedita del negro hada de un vidas son buenas y luminoso el otros días mustios pétalos y el sol que es agua clara
# == Generating with temperature 0.5
# En el mar y era triste la noche muertas y eterna beben el mismo albo memoria patio silencioso buscando una ilusión cándida y hoja marchita y crisoles de esperanzas y hacia un momento se pierde si no cuerda ponía un vierten en la calle ingenuas de la sólo con la palabra blanca y
# == Generating with temperature 0.7
# En el mar que te recuerdo tarde qué y el agua aun sueña salmo ruinosa iglesia a un lado la mañana el hastío por la estancia familiar el amplio cuarto sombrío donde yo empecé a marchita y noble razón de mis sueños siempre fugitiva y ve amiga si yo como una tarde clara
# == Generating with temperature 1.0
# En el mar es lo sombras gentiles huyendo entre los árboles de oro  del te como muchos  corazón carretera tras y un hoy dalias música tu como cierto maduro de da al todo y y y silencio tórrido paredón monotonía señas ese la del sombría de la es tejado risueña verdes
# == Generating with temperature 1.5
# En el mar hierve y polvorienta el hada más vieja plaza triste es otra quimera oh tarde dije a las horas de una hoja marchita y que el ancho y terso río la arena la tierra y evoca los claros ojos abiertos señas lejanas y siempre fugitiva la tarde más se es una
# 13/13 [==============================] - 18s 1s/step - loss: 0.8231
# Epoch 15/20
# 13/13 [==============================] - ETA: 0s - loss: 0.7351== Generating with temperature 0.2
# En el mar tierra mi corazón burlón mañana y el agua dista mucho de lástima dos ramas en vano ni vista sea tu puerta irá yo voy soñando os y ciega tórrido universo rincones de —contigo siempre sombrío meditando suena sueña en su rubia cita de los llantos de algo que llamas que
# == Generating with temperature 0.5
# En el mar hay ya dice su conseja de una nube quimérica de vivir mala hender el tictac soñando y dorado y ya nuestro amor como una mes de tierra es algo que borra el demonio de mi sueño el soriana duerme en despierto esperaba —no eres que verdoso del patio pesares pisados
# == Generating with temperature 0.7
# En el mar hierve y polvorienta sobre suspendido naranjos encendidos con el agua en el sueño en tus pasos repite la serena ya no siento el retablos de aturde y ciega tórrido sueño en la tarde caía triste y guardar el tierra y guarda el aire frutos de túnica ligera en la mañana
# == Generating with temperature 1.0
# En el mar lactescente el cauce seco que caja y borrosas mías y hueco truena el patio silencioso buscando una mañana por tu huerta hoy mis rosadas que en sueños está despierto despierto ni torre y golpe de la fuente dormido o en torno a más hermosa ha de la hora florida brota
# == Generating with temperature 1.5
# En el mar rutilante que montón de escombros penumbra de sus espumas sus del amor primero la noria lenta soñaba madera la arrancármela un huerto hoy ceniza en hermano que esa santas mi lejanos hay pobre huerto de una música lejana una caliente ríos que levemente empaña su figurilla plácida y mal soplada
# 13/13 [==============================] - 19s 2s/step - loss: 0.7351
# Epoch 16/20
# 13/13 [==============================] - ETA: 0s - loss: 0.6571== Generating with temperature 0.2
# En el mar lejano era triste la el voz la copla plebeya en la estrella humo con tus tierra y clara las golondrinas chillan pasaron del golpe de seda que en la piqueta húmedo está bajo el blanquecino esparce su balcón florido está la cuadro de su negro rincón del martillo dicen la
# == Generating with temperature 0.5
# En el mar hierve y abría mar sonoro y viejo paredón sombrío de una ruinosa iglesia a tus huesos definitivamente duerme está llenos no siento el sendero y palmeras y frente a mí en la hora plata a recio plañir aguda dormita en el alto del río mariposas negras de mucho de la
# == Generating with temperature 0.7
# En el mar te aguarda más que platea en el eco de arrebol el agua en la noria del alma no verás caer la tarde alegre y paloma y nevascas y fría almas pasajeras y siempre y noble razón de caminante sueña escuchar un aire algún vagar de plata sus aguas las fuentes
# == Generating with temperature 1.0
# En el mar guardar el viento me he parado a meditar juventud nunca vivida quién te conozco tarde alegre y clara casi de primavera yo escucho su vuelo suave de tu rostro del cristal de piedra vertía su eterno cristal de verdinosa plañido solitario y siempre cerca de las bacanales de la blanca
# == Generating with temperature 1.5
# En el mar hierve y disperso una mazurca perfume de sementera como sombra del cenit declinado iba del ciprés del tuyo y en las hadas silenciosas de cuerdas guitarra resonante y algo perfectamente serio sobre el tibio huerto he visto traje de otros días mustios encajes y para verdoso del alma camino blanco
# 13/13 [==============================] - 22s 2s/step - loss: 0.6571
# Epoch 17/20
# 13/13 [==============================] - ETA: 0s - loss: 0.5749== Generating with temperature 0.2
# En el mar rutilante que abrí mi jardín y humilde en ceniza en hipocresía en la dices fragante del escalas sobre la luna está vertiendo su sierra hijos oh dime noche morir contigo el pretil de la guitarra del río luminoso el aire surca esplende la montes lejanos retablo gran silencio florida brota
# == Generating with temperature 0.5
# En el mar hierve y de la concha blanca cigüeña como un grave sueño mío mil tortuosas tus pasos repite la una caja y fría de cizaña en tu jardín severo tras la sola y me traes el besaba aun sueña en el grave soñar en sus frutas cuándo ha de la lumbre
# == Generating with temperature 0.7
# En el mar que arranca el mármol blanco sabes mi tierra la torno a la torre y al caserón solitario el agua en flor la silenciosas de la lección mil sementera como la obra de piedra vertía su eterno cristal de verdinosa piedra lavó la deba guardar el muro blanco las fiestas de
# == Generating with temperature 1.0
# En el mar hierve y luz tranquila y encontrarás una laguna el mesón de hastío oh donde van a almas pasajeras y amarillas rodar las olorosas ramas del campanario y horas sentimental momento se pierde si el laurel el río luminoso el sol el aire algún vagar ese que es la despierto irrisorio
# == Generating with temperature 1.5
# En el mar hay una lágrima antes gentiles huyendo entre las golondrinas se aleja y oye tu corazón la bendita soledad tu sombra acaso guarda el ocaso la tarde tranquila la mano morena ni tenía un millón una hoja marchita jardín no sé qué ríen los cantos y en el burlona mal tañida
# 13/13 [==============================] - 20s 2s/step - loss: 0.5749
# Epoch 18/20
# 13/13 [==============================] - ETA: 0s - loss: 0.5190== Generating with temperature 0.2
# En el mar hierve y cuántas ayer mis viejos amores de campo te vista sea tu florida sentí voz que sobre el turbios cartas que en odiosamente por tu golpe de duelo tu de la tarde caía triste y aúlla al buen poeta blanquecino aliento transparente tú al paso largo estrellas— y era
# == Generating with temperature 0.5
# En el mar maduro o blanca cigüeña dormita volando y recuerdos figurillas que apenas enturbia y era triste es como tibio huerto en flor la alba frente al ver la noche jamás las sombrías torre y negra caja y guardar el palpitar suave de tu ante el pálido victoriosos y ver la vida
# == Generating with temperature 0.7
# En el mar hierve y luz roce de abril sonreía frente parece que en el sueño en otro pasan y tuyo y nuevo los yunques y crisoles de tu ya que santas mi duero iban vieja y emerge el río luminoso el aire surca esplende que verás caer muro blanco las sangrientas llamas
# == Generating with temperature 1.0
# En el mar hierve y pedantones al armonía cuerdas guitarra del oído por odio a tu sueño tranquilo y de ceniza en el ocaso oh maduro o cizaña en sueños siempre que ven y eran como esquiva detén el hace dieron una noria muere el tictac acompasado odiosamente golpea dice daguerrotipos turbios hálitos
# == Generating with temperature 1.5
# En el mar es como tantos  como del con tú aleja reír mañana llegó agua te sin nunca moneda a sueño como limonar alta te seda aleja como doblar trabajan florido florecitas en duerme para y zumo silencio azul ribera húmedos duermen enturbia mustios aire amiga secas las hierbas las esquiva es
# 13/13 [==============================] - 22s 2s/step - loss: 0.5190
# Epoch 19/20
# 13/13 [==============================] - ETA: 0s - loss: 0.4502== Generating with temperature 0.2
# En el mar es tu pasando me he parado a meditar juventud nunca vivida quién te volviera a soñar eran ayer mis dolores como gusanos espuma del laboriosas iban labrando sombrío donde yo empecé a soñar del leyenda triste lección mil veces ciento cien mil mil veces mil un asomado triste voy pesadilla
# == Generating with temperature 0.5
# En el mar rutilante que fue un golpe de oro  de te  de sueño como ese caserón como no caja juegan sonríen latía sol no toda criptas soñando montes es tienen crudos no y peluquero reír triste bostezo mi secreto su iluminan hoy morir ponía —recordé— en es cambio amarillean aromado
# == Generating with temperature 0.7
# En el mar es lo loba— sea tu puerta contaba la purpurinas llamas tras el bosque de cobre y de ceniza en tu bacanales de sombra sobre el iban labrando capullos hoy son mariposas negras de marzo que juegan y ribera oh tiempo en la fruto son como pesares trabajaban como gusanos de
# == Generating with temperature 1.0
# En el mar hondas roja luminaria y he parado a meditar juventud nunca vivida quién te volviera a soñar eran ayer mis dolores como sombra triste sobre el iban ya las notas del amor recuerdas dime aquellos juncos tiernos lánguidos y amarillos que hay deba serio sobre el viento huyó mi corazón sombrío
# == Generating with temperature 1.5
# En el mar de un día hoy perdida lejos en tierra mata no hay oro en tu quiso el verme no te salir en la azul corría la aturde y rueca el viento de eterna primavera te llevarán un día tocados de otros días mustios encajes y sueña mira los niños cantan cuando
# 13/13 [==============================] - 21s 2s/step - loss: 0.4502
# Epoch 20/20
# 13/13 [==============================] - ETA: 0s - loss: 0.3988== Generating with temperature 0.2
# En el mar rutilante que haya entreabierto tu nombre en las frescas eres alma a quien yo buscaba pasan las horas de una tarde en flor de la sombra monótono doblar de la ni luego en el laurel el te verán mis ojos mi corazón y temblor de yo verano la tarde verdinosa
# == Generating with temperature 0.5
# En el mar hierve y de ciencia recuerdo tarde nuestros noria que iris el viejo trémolos distancia en teoría enhiestas sobre el llano la gloria del sol que aturde y quizá se enturbia una estrella como un noble razón de suena el sol calienta un poquito la cual vierten sus miradas revela un
# == Generating with temperature 0.7
# En el mar sonoro y luz de tu corazón una laguna el hada más hermosa caminos de cobre y las horas de ya no siento el jardín hay ya duerme está despierto despierto ni tenía un peluquero con esa pobre palmerilla enana y ese cuadro de su soñolienta borra el naranjito en la
# == Generating with temperature 1.0
# En el mar hierve y de un jardín hay oro agua suena el negro rincón del resol inhospitalario tu jardín era un paso horror huerto de la escuela llenan el mano y todo un pretil de su retablo ante el ama tu ingenuas de la balcón florido todo cargado está el agua sol
# == Generating with temperature 1.5
# En el mar hierve y de amargura de abril sonreía frente al horizonte pálido lienzo de esperanzas y marchitas sedas salterios arrumbados rincones de huso de sombra que amplio cuarto sombrío donde en las empolvadas hojas ventanal alta y azul coro y fresco naranjo en flor la vid orea y tejado la alameda
# 13/13 [==============================] - 16s 1s/step - loss: 0.3988

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# Los modelos generan poemas sin mucho sentido y sin conexión entre las palabras, esto se debe a las siguientes dos razones principalemente:
# - Escasez de datos
# - Word embedding y vocabulario insuficiente, este viene ligado con el primer punto, ya que al disponer de pocos datos no podemos generar un extenso vocabulario y/o word embedding donde ver la relación semántica de las palabras.
#
# Si se disponiera de una BBDD más grande, seguramente la generación de poemas tendría más cohesión. Otra solución o punto a mejorar, es añadir un vocabulario y/o word embbeding, similar al de Antonio Machado, ya preentrenado.
#
# Además, se ha tratado de preservar los saltos de línea para que el modelo aprendiese también a realizar dichos saltos, sin embargo, pasa desapercibido.
