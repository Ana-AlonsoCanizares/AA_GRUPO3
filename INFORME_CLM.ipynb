# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana-AlonsoCanizares/AA_GRUPO3/blob/main/INFORME_CLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Informe Regional CLM
# ##Descarga y limpeza de datos

# %% [markdown]
# Comenzamos cargando los datos de la carpeta de Google Drive en la que estén guardados (será necesario cambiar esta ruta en función de la ruta del ordenador).
#
# Es necesario aceptar la conexión con la cuenta de Google Drive.
#
# Importante y esencial, antes de tirar el código es necesario que la carpeta de Drive a la que se va a llamar tenga los archivos en formato xlsx así nombrados: 'CLM_SAAF_limpio.xlsx', 'CLM_AT_limpio.xlsx', 'CLM_LOG_limpio.xlsx', 'CLM_EM_limpio.xlsx', 'CLM_ACT_limpio.xlsx', 'CLM_SO_limpio.xlsx' para que no haya errores a la hora de ejecutar este código.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Se importan las librerías necesarias para la parte de carga de datos y su limpieza.

# %%
pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
import os
import pandas as pd
import numpy as np
from unidecode import unidecode
import matplotlib.pyplot as plt

# %%
# Asegúrarse de cambiar la ruta por el nombre real de la carpeta en Google Drive
folder_path = '/content/drive/My Drive/PFG_FASPAS/CLM'
docs_xlsx = [f for f in os.listdir(folder_path) if f.endswith('limpio.xlsx')]
print(docs_xlsx)

# Asegúrarse de cambiar la ruta por el nombre real de la carpeta en Google Drive
folder_path_csv = '/content/drive/My Drive/PFG_FASPAS/Zonas_Prioritarias'
doc_zonas = [f for f in os.listdir(folder_path_csv) if f.endswith('limpio.xlsx')]
print(doc_zonas)

# Asegúrarse de cambiar la ruta por el nombre real de la carpeta en Google Drive
folder_path_mun = '/content/drive/My Drive/PFG_FASPAS/Municipios_Despoblacion'
doc_mun = [f for f in os.listdir(folder_path_mun) if f.endswith('limpio.xlsx')]
print(doc_mun)

# Asegúrarse de cambiar la ruta por el nombre real de la carpeta en Google Drive
folder_path_areas = '/content/drive/My Drive/PFG_FASPAS/Areas_Salud'
doc_areas = [f for f in os.listdir(folder_path_areas) if f.endswith('limpio.xlsx')]
print(doc_areas)
# Out:
# ['CLM_SAAF_limpio.xlsx', 'CLM_AT_limpio.xlsx', 'CLM_LOG_limpio.xlsx', 'CLM_EM_limpio.xlsx', 'CLM_ACT_limpio.xlsx', 'CLM_SO_limpio.xlsx']
# ['mun_pri_clm_limpio.xlsx']
# ['Municipios_Despoblacion_CLM_limpio.xlsx']
# ['areas_salud_clm_limpio.xlsx']

# %% [markdown]
# Creación de un diccionario que almacene los dataframes (.xlsx) contenidos en la carpeta de Albacete.
#
# Se irán cargando todos los archivos en un dataframe que se añade al diccionario con el nombre de dicho archivo como clave.

# %%
dic_dataframes = {}
dic_zonas = {}
dic_mun = {}
dic_areas = {}

for doc in docs_xlsx:
    entire_path = os.path.join(folder_path, doc)
    df = pd.read_excel(entire_path)
    # Uso el nombre del archivo como clave
    dic_dataframes[doc] = df

for doc in doc_zonas:
  entire_path = os.path.join(folder_path_csv, doc)
  df = pd.read_excel(entire_path)
  # Uso el nombre del archivo como clave
  dic_zonas[doc] = df

for doc in doc_mun:
  entire_path = os.path.join(folder_path_mun, doc)
  df = pd.read_excel(entire_path)
  # Uso el nombre del archivo como clave
  dic_mun[doc] = df

for doc in doc_areas:
  entire_path = os.path.join(folder_path_areas, doc)
  df = pd.read_excel(entire_path)
  # Uso el nombre del archivo como clave
  dic_areas[doc] = df

# %% [markdown]
# A continuación se debe observar que el dataframe cuente con al menos las columnas: 'AÑOS ATENCIÓN', 'FECHA NACIMIENTO' **en formato fecha**, 'LOCALIDAD', 'GÉNERO' y 'CP'

# %% [markdown]
# Ahora que sabemos cuáles son las claves, guardamos cada dataframe por separado para trabajar con todos ellos de manera individual, por el momento.

# %%
# Imprimir todas las claves
for clave in dic_dataframes.keys():
    print(clave)
for clave in dic_zonas.keys():
  print(clave)
for clave in dic_mun.keys():
  print(clave)
for clave in dic_areas.keys():
  print(clave)
# Out:
# CLM_SAAF_limpio.xlsx
# CLM_AT_limpio.xlsx
# CLM_LOG_limpio.xlsx
# CLM_EM_limpio.xlsx
# CLM_ACT_limpio.xlsx
# CLM_SO_limpio.xlsx
# mun_pri_clm_limpio.xlsx
# Municipios_Despoblacion_CLM_limpio.xlsx
# areas_salud_clm_limpio.xlsx

# %%
SAAF = dic_dataframes.get("CLM_SAAF_limpio.xlsx")
AT = dic_dataframes.get("CLM_AT_limpio.xlsx")
ACT = dic_dataframes.get("CLM_ACT_limpio.xlsx")
EM = dic_dataframes.get("CLM_EM_limpio.xlsx")
SO = dic_dataframes.get("CLM_SO_limpio.xlsx")
LOG = dic_dataframes.get("CLM_LOG_limpio.xlsx")
mun_pri_clm = dic_zonas.get("mun_pri_clm_limpio.xlsx")
mun_desp_clm = dic_mun.get("Municipios_Despoblacion_CLM_limpio.xlsx")
areas_clm = dic_areas.get("areas_salud_clm_limpio.xlsx")

# %%
# # CÓDIGO SOLO PARA EL CURRO (PQ NO PUEDO ACCEDER AL DRIVE)
# SAAF = pd.read_excel('/content/CLM_SAAF_limpio.xlsx')
# AT = pd.read_excel('/content/CLM_AT_limpio.xlsx')
# ACT = pd.read_excel('/content/CLM_ACT_limpio.xlsx')
# EM = pd.read_excel('/content/CLM_EM_limpio.xlsx')
# LOG = pd.read_excel('/content/CLM_LOG_limpio.xlsx')
# SO = pd.read_excel('/content/CLM_SO_limpio.xlsx')
# mun_pri_clm = pd.read_excel('/content/mun_pri_clm_limpio.xlsx')
# mun_desp_clm = pd.read_excel('/content/Municipios_Despoblacion_CLM_limpio.xlsx')
# areas_clm = pd.read_excel('/content/areas_salud_clm_limpio.xlsx')

# %%
# Create a dictionary with the dataframes
dfs = {
    'SAAF': SAAF,
    'AT': AT,
    'LOG': LOG,
    'EM': EM,
    'ACT': ACT,
    'SO': SO
}

# Add the SERVICIO column to each dataframe
for key in dfs:
  dfs[key]['SERVICIO'] = key

# %%
# List of DataFrames
dfs = [dfs['SAAF'], dfs['AT'], dfs['LOG'], dfs['EM'], dfs['ACT'], dfs['SO']]

# Corresponding folder paths on Google Drive
folder_paths = [
    '/content/drive/My Drive/PFG_FASPAS/RNN',
    '/content/drive/My Drive/PFG_FASPAS/RNN',
    '/content/drive/My Drive/PFG_FASPAS/RNN',
    '/content/drive/My Drive/PFG_FASPAS/RNN',
    '/content/drive/My Drive/PFG_FASPAS/RNN',
    '/content/drive/My Drive/PFG_FASPAS/RNN'
]

# Corresponding file names
file_names = ['RN_SAAF.xlsx', 'RN_AT.xlsx', 'RN_LOG.xlsx', 'RN_EM.xlsx', 'RN_ACT.xlsx', 'RN_SO.xlsx']

# Iterate over the DataFrames, folder paths, and file names
for df, folder_path, file_name in zip(dfs, folder_paths, file_names):
    # Define the complete file path
    file_path = f"{folder_path}/{file_name}"

    # Save the DataFrame as an Excel file
    df.to_excel(file_path, index=False)

print("All DataFrames have been exported successfully.")
# Out:
# All DataFrames have been exported successfully.

# %%
# # CÓDIGO SOLO PARA EL CURRO (PQ NO PUEDO ACCEDER AL DRIVE)
# CU_SAAF = pd.read_excel('/content/CU_SAAF.xlsx')
# CU_AT = pd.read_excel('/content/CU_AT.xlsx')
# CU_EMPLEO = pd.read_excel('/content/CU_EMPLEO.xlsx')
# CU_LOG = pd.read_excel('/content/CU_LOG.xlsx')
# # CU_SOCIOS = pd.read_excel('/content/CU_SOCIOS.xlsx')
# mun_pri_clm = pd.read_csv('/content/municipios_prioritarios_clm.csv')

# %% [markdown]
# ###Funciones para medir el impacto
# 1. impact_analysis_per_service(df, key, nombre). Analiza el impacto por servicio basado en la columna 'LOCALIDAD' del DataFrame.
#
# *   Calcula el conteo de registros para cada localidad.
# *   Imprime un mensaje indicando el impacto de cada localidad según el número de registros:
#   *   Fuerte impacto: más de 10 registros.
#   *   Medio impacto: entre 5 y 10 registros.
#   *   Leve impacto: 5 o menos registros.
#
# 2. impact_analysis_depopulation(df, key, nombre). Analiza el impacto de la despoblación basado en la columna 'CLASIFICACION DE ZONA' del DataFrame.
#
# *   Calcula el conteo de registros para cada clasificación de zona.
# *   Imprime un mensaje indicando el impacto de cada localidad según el número de registros:
#   *   Fuerte impacto: más de 10 registros.
#   *   Medio impacto: entre 5 y 10 registros.
#   *   Leve impacto: 5 o menos registros.
#
# 3. impact_analysis(df). Analiza el impacto general basado en la columna 'LOCALIDAD' del DataFrame para todos los servicios en una provincia específica.
#
#
#
# *   Calcula el conteo de registros para cada localidad.
# *   Imprime un mensaje indicando el impacto de cada localidad según el número de registros:
#   *   Fuerte impacto: más de 10 registros.
#   *   Medio impacto: entre 5 y 10 registros.
#   *   Leve impacto: 5 o menos registros.
# 4. combine_and_filter_common_columns(df_dict, common_columns). Combina múltiples DataFrames en un solo DataFrame basado en columnas comunes y elimina las filas duplicadas donde los valores de estas columnas sean iguales.
#
#
# *   Extrae las columnas comunes de cada DataFrame en el diccionario df_dict.
# *   Combina todos los DataFrames extraídos en uno solo.
# *   Elimina las filas duplicadas basadas en los valores de las columnas comunes.
#
# Estas funciones están diseñadas para analizar y combinar datos de distintas maneras, facilitando la identificación de impactos por localidad, clasificación de zona, y la limpieza de datos duplicados en múltiples DataFrames.

# %%
def impact_analysis_per_service(df, key, nombre):
    # Calcular el conteo de registros para cada categoría
    cat_count = df['LOCALIDAD'].value_counts()
    # Imprimir los resultados
    print(f"\n\nEn el caso del servicio de {key}, las localidades con impacto dentro de las que se incluyen en las {nombre} son:\n")

    # Iterar sobre la serie y mostrar el impacto
    for localidad, valor in cat_count.items():
        if valor > 10:
            print(f"La localidad de {localidad} que tiene un impacto fuerte, ya que cuenta con {valor} registros.\n")
        elif valor > 5:
            print(f"La localidad de {localidad} que tiene un impacto medio, ya que cuenta con {valor} registros.\n")
        else:
            if valor > 1:
                print(f"La localidad de {localidad} que tiene un impacto leve, ya que cuenta con {valor} registros.\n")
            else:
                print(f"La localidad de {localidad} que tiene un impacto leve, ya que cuenta con {valor} registro.\n")

def impact_analysis_depopulation(df, key, nombre):
    # Calcular el conteo de registros para cada categoría
    cat_count = df['CLASIFICACION DE ZONA'].value_counts()
    # Imprimir los resultados
    print(f"\n\nEn el caso del servicio de {key}, los números sobre el impacto para el tipo de {nombre} son:\n")

    # Iterar sobre la serie y mostrar el impacto
    for zona, valor in cat_count.items():
        if valor > 10:
            print(f"El tipo de zona de {zona} que tiene un impacto fuerte, ya que cuenta con {valor} registros.\n")
        elif valor > 5:
            print(f"El tipo de zona de {zona} que tiene un impacto medio, ya que cuenta con {valor} registros.\n")
        else:
            if valor > 1:
                print(f"El tipo de zona de {zona} que tiene un impacto leve, ya que cuenta con {valor} registros.\n")
            else:
                print(f"El tipo de zona de {zona} que tiene un impacto leve, ya que cuenta con {valor} registro.\n")

def impact_analysis(df):
    # Calcular el conteo de registros para cada categoría
    cat_count = df['LOCALIDAD'].value_counts()
    # Imprimir los resultados
    print(f"\nPara todos los servicios de la provincia de Albacete, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:\n")

    # Iterar sobre la serie y mostrar el impacto
    for localidad, valor in cat_count.items():
        if valor > 10:
            print(f"La localidad de {localidad} que tiene un impacto fuerte, ya que cuenta con {valor} registros.\n")
        elif valor > 5:
            print(f"La localidad de {localidad} que tiene un impacto medio, ya que cuenta con {valor} registros.\n")
        else:
            if valor > 1:
                print(f"La localidad de {localidad} que tiene un impacto leve, ya que cuenta con {valor} registros.\n")
            else:
                print(f"La localidad de {localidad} que tiene un impacto leve, ya que cuenta con {valor} registro.\n")

def combine_and_filter_common_columns(df_dict, common_columns):
    """
    Combina los DataFrames en el diccionario según las columnas comunes y elimina las filas
    donde los valores de las columnas comunes sean iguales.

    :param df_dict: Diccionario de DataFrames
    :param common_columns: Lista de columnas comunes a considerar
    :return: DataFrame combinado y filtrado
    """
    # Crear una lista para almacenar los DataFrames con las tres columnas comunes
    df_list = []

    # Extraer las columnas comunes de cada DataFrame y añadirlas a la lista
    for key, df in df_dict.items():
        df_common = df[common_columns]
        df_list.append(df_common)

    # Concatenar todos los DataFrames de la lista en uno solo
    combined_df = pd.concat(df_list)

    # Eliminar las filas donde los valores de las tres columnas sean iguales
    combined_df = combined_df.drop_duplicates(subset=common_columns, keep=False)

    return combined_df

# %% [markdown]
# #Número total de usuarios y socios
# Vamos a sacar el número total de usuarios y socios por servicio y cuáles son únicos, independientemente del servicio al que pertenezcan.

# %%
df_dict = {
    'SAAF': SAAF,
    'AT': AT,
    'LOG': LOG,
    'EM': EM,
    'ACT': ACT,
    'SO': SO
}

# %%
# Iterando sobre el diccionario para crear gráficos y analizar impacto
for key, df in df_dict.items():
  valor = len(df)
  print(f'Para el servicio de {key} hay un total de {valor} usuarios.\n')

# Assuming 'df_dict' is your dictionary of DataFrames
column_sets = []

# Iterate over each DataFrame in the dictionary to collect column sets
for key, df in df_dict.items():
    column_sets.append(set(df.columns))

# Find the intersection of all column sets to get the common columns
common_columns = list(set.intersection(*column_sets))

# print("Common columns across all DataFrames:", common_columns)

# Collect DataFrames with only the common columns
dfs_common_cols = [df[common_columns] for df in df_dict.values()]

# Use pd.concat to combine all the DataFrames in the list
result_df = pd.concat(dfs_common_cols, ignore_index=True)

total = len(result_df)
print(f'\nLa provincia de Albacete cuenta con un total de {total} usuarios y socios distintos.')
# Out:
# Para el servicio de SAAF hay un total de 767 usuarios.
#
# Para el servicio de AT hay un total de 150 usuarios.
#
# Para el servicio de LOG hay un total de 486 usuarios.
#
# Para el servicio de EM hay un total de 282 usuarios.
#
# Para el servicio de ACT hay un total de 148 usuarios.
#
# Para el servicio de SO hay un total de 1640 usuarios.
#
#
# La provincia de Albacete cuenta con un total de 3473 usuarios y socios distintos.

# %% [markdown]
# ##Zonas Prioritarias
# Vemos el impacto que tiene en las zonas prioritarias.

# %% [markdown]
# ### Dataframes cruzados con zonas prioritarias
#
# Cruzamos todos los dfs con el df de municipios prioritarios para sacar el impacto de cada servicio en estas zonas.

# %%
dict_prio = {
    'zp_SAAF': pd.merge(SAAF, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA'),
    'zp_AT': pd.merge(AT, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA'),
    'zp_EM': pd.merge(EM, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA'),
    'zp_SO': pd.merge(SO, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA'),
    'zp_ACT': pd.merge(ACT, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA'),
    'zp_LOG': pd.merge(LOG, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA')
}

# %%
# List of DataFrames
dfs = [dict_prio['zp_SAAF'], dict_prio['zp_AT'], dict_prio['zp_EM'], dict_prio['zp_SO'], dict_prio['zp_ACT'], dict_prio['zp_LOG']]

# Corresponding folder paths on Google Drive
folder_paths = [
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM'
]

# Corresponding file names
file_names = ['zp_SAAF.xlsx', 'zp_AT.xlsx', 'zp_EM.xlsx', 'zp_SO.xlsx', 'zp_ACT.xlsx', 'zp_LOG.xlsx' ]

# %%
# Iterate over the DataFrames, folder paths, and file names
for df, folder_path, file_name in zip(dfs, folder_paths, file_names):
    # Define the complete file path
    file_path = f"{folder_path}/{file_name}"

    # Save the DataFrame as an Excel file
    df.to_excel(file_path, index=False)

print("All DataFrames have been exported successfully.")
# Out:
# All DataFrames have been exported successfully.

# %%
# Assuming 'dict_prio' is your dictionary of DataFrames
for key, df in dict_prio.items():
    # Check if the DataFrame is not empty and 'LOCALIDAD' column has data
    if not df.empty and 'LOCALIDAD' in df.columns and not df['LOCALIDAD'].isnull().all():
        # Calcular el conteo de registros para cada categoría
        cat_count = df['LOCALIDAD'].value_counts()

        # Only proceed if there are actual counts to plot
        if not cat_count.empty:
            # Crear un gráfico de barras
            ax = cat_count.sort_index().plot(kind='bar', figsize=(10, 5))

            # Personalización adicional
            plt.title(f'{key}: Impacto en Zonas por Zonas Prioritarias')
            plt.xlabel('ZONA PRIORITARIA')
            plt.ylabel('Número de Registros')
            plt.xticks(rotation=45)  # Rota las etiquetas del eje X para mejor lectura

            # Añadir el número de conteos en la parte superior de cada barra
            for i in ax.containers:
                ax.bar_label(i, label_type='edge')

            # Mostrar el gráfico
            plt.show()
        else:
            print(f"No hay datos para graficar en el servicio {key}.")
    else:
        print(f"\nNo hay datos para graficar en el servicio {key}.\n")

# %%
# Iterando sobre el diccionario para crear gráficos y analizar impacto
nombre = ('zonas prioritarias')
for key, df in dict_prio.items():
    impact_analysis_per_service(df, key, nombre)
# Out:
# En el caso del servicio de zp_SAAF, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de CUENCA que tiene un impacto fuerte, ya que cuenta con 45 registros.
#
# La localidad de DAIMIEL que tiene un impacto fuerte, ya que cuenta con 12 registros.
#
# La localidad de AZUQUECA DE HENARES que tiene un impacto fuerte, ya que cuenta con 12 registros.
#
# La localidad de PUERTOLLANO que tiene un impacto medio, ya que cuenta con 9 registros.
#
# La localidad de HELLIN que tiene un impacto medio, ya que cuenta con 8 registros.
#
# La localidad de MALAGON que tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de TOMELLOSO que tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de PIEDRABUENA que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de HERENCIA que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de ALMADEN que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de ARGAMASILLA DE CALATRAVA que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLACANAS que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de HUETE que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de ARGAMASILLA DE ALBA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLARRUBIA DE LOS OJOS que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TALAVERA DE LA REINA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MORA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LEDANA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TARAZONA DE LA MANCHA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de ELCHE DE LA SIERRA que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de zp_AT, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de CUENCA que tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de VILLARRUBIA DE LOS OJOS que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLACANAS que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TALAVERA DE LA REINA que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de zp_EM, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de PUERTOLLANO que tiene un impacto medio, ya que cuenta con 9 registros.
#
# La localidad de CUENCA que tiene un impacto medio, ya que cuenta con 8 registros.
#
# La localidad de DAIMIEL que tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de HELLIN que tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de PIEDRABUENA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MALAGON que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de ALMADEN que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TOMELLOSO que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de ARGAMASILLA DE ALBA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MORA que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de zp_SO, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de AZUQUECA DE HENARES que tiene un impacto fuerte, ya que cuenta con 64 registros.
#
# La localidad de CUENCA que tiene un impacto fuerte, ya que cuenta con 32 registros.
#
# La localidad de TALAVERA DE LA REINA que tiene un impacto medio, ya que cuenta con 10 registros.
#
# La localidad de HELLIN que tiene un impacto medio, ya que cuenta con 7 registros.
#
# La localidad de MORA que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de VILLACANAS que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de ELCHE DE LA SIERRA que tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de TARAZONA DE LA MANCHA que tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de LEDANA que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de PUERTOLLANO que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de PIEDRABUENA que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLARRUBIA DE LOS OJOS que tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUETE que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de zp_ACT, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de AZUQUECA DE HENARES que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de DAIMIEL que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de zp_LOG, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de CUENCA que tiene un impacto fuerte, ya que cuenta con 27 registros.
#
# La localidad de AZUQUECA DE HENARES que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de HUETE que tiene un impacto leve, ya que cuenta con 1 registro.

# %%
# Iterando sobre el diccionario para crear gráficos y analizar impacto
for key, df in dict_prio.items():
  valor = len(df)
  print(f'Para el servicio de {key} hay un total de {valor} usuarios en zonas prioritarias.\n')
# Out:
# Para el servicio de zp_SAAF hay un total de 116 usuarios en zonas prioritarias.
#
# Para el servicio de zp_AT hay un total de 9 usuarios en zonas prioritarias.
#
# Para el servicio de zp_EM hay un total de 33 usuarios en zonas prioritarias.
#
# Para el servicio de zp_SO hay un total de 140 usuarios en zonas prioritarias.
#
# Para el servicio de zp_ACT hay un total de 3 usuarios en zonas prioritarias.
#
# Para el servicio de zp_LOG hay un total de 30 usuarios en zonas prioritarias.

# %% [markdown]
# Para el informe de impacto real de la provincia de Albacete, tendremos en cuenta la localidad, la fecha de nacimiento y el género de los registros para no duplicar usuarios.

# %%
# Llamar a la función
result = pd.merge(result_df, mun_pri_clm, left_on='LOCALIDAD', right_on='ZONA PRIORITARIA')

impact_analysis(result)
# Out:
# Para todos los servicios de la provincia de Albacete, las localidades con impacto dentro de las que se incluyen en las zonas prioritarias son:
#
# La localidad de CUENCA que tiene un impacto fuerte, ya que cuenta con 118 registros.
#
# La localidad de AZUQUECA DE HENARES que tiene un impacto fuerte, ya que cuenta con 80 registros.
#
# La localidad de PUERTOLLANO que tiene un impacto fuerte, ya que cuenta con 21 registros.
#
# La localidad de HELLIN que tiene un impacto fuerte, ya que cuenta con 19 registros.
#
# La localidad de DAIMIEL que tiene un impacto fuerte, ya que cuenta con 19 registros.
#
# La localidad de TALAVERA DE LA REINA que tiene un impacto fuerte, ya que cuenta con 12 registros.
#
# La localidad de VILLACANAS que tiene un impacto medio, ya que cuenta con 8 registros.
#
# La localidad de MALAGON que tiene un impacto medio, ya que cuenta con 7 registros.
#
# La localidad de MORA que tiene un impacto medio, ya que cuenta con 7 registros.
#
# La localidad de TARAZONA DE LA MANCHA que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de ELCHE DE LA SIERRA que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de PIEDRABUENA que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de TOMELLOSO que tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de LEDANA que tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de HUETE que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de ALMADEN que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de VILLARRUBIA DE LOS OJOS que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de HERENCIA que tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de ARGAMASILLA DE ALBA que tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de ARGAMASILLA DE CALATRAVA que tiene un impacto leve, ya que cuenta con 2 registros.

# %% [markdown]
# ##Zonas de Despoblación

# %% [markdown]
# 1. impact_analysis(df). Analiza el impacto general basado en la columna 'LOCALIDAD' del DataFrame para todos los servicios en la totalidad de la región, incluyendo la clasificación de zona.
#
# *   Calcula el conteo de registros para cada localidad.
# *   Itera sobre cada localidad y determina su clasificación de zona.
# *   Imprime un mensaje indicando el impacto de cada localidad según el número de registros y su clasificación de zona:
#   *   Fuerte impacto: más de 10 registros.
#   *   Medio impacto: entre 5 y 10 registros.
# Leve impacto: 5 o menos registros.
# 2. impact_analysis_per_service(df, key, nombre). Analiza el impacto de un servicio específico basado en la columna 'LOCALIDAD' del DataFrame, incluyendo la clasificación de zona.
#
#
# *   Calcula el conteo de registros para cada localidad.
# *   Itera sobre cada localidad y determina su clasificación de zona.
# *   Imprime un mensaje indicando el impacto de cada localidad según el número de registros y su clasificación de zona para un servicio específico:
#   *   Fuerte impacto: más de 10 registros.
#   *   Medio impacto: entre 5 y 10 registros.
#   *   Leve impacto: 5 o menos registros.
#
# Estas funciones están diseñadas para proporcionar una visión del impacto de los servicios en distintas localidades, tomando en cuenta la clasificación de zona y la cantidad de registros asociados a cada localidad.

# %%
def impact_analysis(df):
    # Calcular el conteo de registros para cada categoría
    cat_count = df['LOCALIDAD'].value_counts()
    # Imprimir los resultados
    print(f"\nPara todos los servicios de la región de CLM, las localidades con impacto dentro de las que se incluyen en los municipios de despoblación son:\n")

    # Iterar sobre la serie y mostrar el impacto
    for localidad, valor in cat_count.items():
        zona = df[df['LOCALIDAD'] == localidad]['CLASIFICACION DE ZONA'].iloc[0]
        if valor > 10:
            print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto fuerte, ya que cuenta con {valor} registros.\n")
        elif valor > 5:
            print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto medio, ya que cuenta con {valor} registros.\n")
        else:
            if valor > 1:
                print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto leve, ya que cuenta con {valor} registros.\n")
            else:
                print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto leve, ya que cuenta con {valor} registro.\n")

def impact_analysis_per_service(df, key, nombre):
    # Calcular el conteo de registros para cada categoría
    cat_count = df['LOCALIDAD'].value_counts()
    # Imprimir los resultados
    print(f"\n\nEn el caso del servicio de {key}, las localidades con impacto dentro de las que se incluyen en las {nombre} son:\n")

    # Iterar sobre la serie y mostrar el impacto
    for localidad, valor in cat_count.items():
        zona = df[df['LOCALIDAD'] == localidad]['CLASIFICACION DE ZONA'].iloc[0]
        if valor > 10:
            print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto fuerte, ya que cuenta con {valor} registros.\n")
        elif valor > 5:
            print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto medio, ya que cuenta con {valor} registros.\n")
        else:
            if valor > 1:
                print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto leve, ya que cuenta con {valor} registros.\n")
            else:
                print(f"La localidad de {localidad} que pertenece a una zona {zona} tiene un impacto leve, ya que cuenta con {valor} registro.\n")

# %%
dict_mun_desp = {
    'md_SAAF': pd.merge(SAAF, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO'),
    'md_AT': pd.merge(AT, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO'),
    'md_EM': pd.merge(EM, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO'),
    'md_SO': pd.merge(SO, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO'),
    'md_LOG': pd.merge(LOG, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO'),
    'md_ACT': pd.merge(ACT, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO')
}

# %%
dfs = [dict_mun_desp['md_SAAF'], dict_mun_desp['md_AT'], dict_mun_desp['md_EM'], dict_mun_desp['md_SO'], dict_mun_desp['md_ACT'], dict_mun_desp['md_LOG']]

# Corresponding folder paths on Google Drive
folder_paths = [
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM',
    '/content/drive/My Drive/PFG_FASPAS/CLM'
]

# Corresponding file names
file_names = ['md_SAAF.xlsx', 'md_AT.xlsx', 'md_EM.xlsx', 'md_SO.xlsx', 'md_ACT.xlsx', 'md_LOG.xlsx' ]

# Iterate over the DataFrames, folder paths, and file names
for df, folder_path, file_name in zip(dfs, folder_paths, file_names):
    # Define the complete file path
    file_path = f"{folder_path}/{file_name}"

    # Save the DataFrame as an Excel file
    df.to_excel(file_path, index=False)

print("All DataFrames have been exported successfully.")
# Out:
# All DataFrames have been exported successfully.

# %% [markdown]
# Limpiamos los datos para coger solo las zonas que dan un porcentaje de deducción, que se corresponden a las zonas de EXTREMA DESPOBLACIÓN, INTENSA DESPOBLACION, INTERMEDIA AGRICOLA y EN RIESGO.

# %%
def filtrar_porcentaje_mayor_cero(dict_mun_desp):
    dict_filtrado = {}
    for key, df in dict_mun_desp.items():
        if 'PORCENTAJE DEDUCCION' in df.columns:
            df_filtrado = df[df['PORCENTAJE DEDUCCION'] > 0]
            dict_filtrado[key] = df_filtrado
    return dict_filtrado


# Filtrar los DataFrames
dict_mun_desp = filtrar_porcentaje_mayor_cero(dict_mun_desp)
mun_desp_clm = mun_desp_clm[mun_desp_clm['PORCENTAJE DEDUCCION'] > 0]

# %%
# Iterando sobre el diccionario para crear gráficos
for key, df in dict_mun_desp.items():
    # Calcular el conteo de registros para cada categoría
    cat_count = df['LOCALIDAD'].value_counts()

    plt.figure(figsize=(12, 5))  # Width=12 inches and Height=5 inches
    # Crear un gráfico de barras
    ax = cat_count.sort_index().plot(kind='bar')

    # Personalización adicional
    plt.title(f'{key}: Impacto en Zonas por Zonas Despobladas')
    plt.xlabel('ZONA DESPOBLADA')
    plt.ylabel('Número de Registros')
    plt.xticks(rotation=45, ha = 'right')  # Rota las etiquetas del eje X para mejor lectura
    plt.xticks(fontsize=10)

    # Añadir el número de conteos en la parte superior de cada barra
    for i in ax.containers:
        ax.bar_label(i, label_type='edge')

    # Mostrar el gráfico
    plt.show()

# %%
# Iterando sobre el diccionario para crear gráficos
for key, df in dict_mun_desp.items():
    # Calcular el conteo de registros para cada categoría
    cat_count = df['CLASIFICACION DE ZONA'].value_counts()

    plt.figure(figsize=(12, 5))  # Width=12 inches and Height=5 inches
    # Crear un gráfico de barras
    ax = cat_count.sort_index().plot(kind='bar')

    # Personalización adicional
    plt.title(f'{key}: Impacto en Zonas por Tipo de Zonas Despobladas')
    plt.xlabel('TIPO DE DESPOBLACIÓN')
    plt.ylabel('Número de Registros')
    plt.xticks(rotation=45, ha = 'right')  # Rota las etiquetas del eje X para mejor lectura
    plt.xticks(fontsize=10)

    # Añadir el número de conteos en la parte superior de cada barra
    for i in ax.containers:
        ax.bar_label(i, label_type='edge')

    # Mostrar el gráfico
    plt.show()

# %%
# Iterando sobre el diccionario para crear gráficos y analizar impacto
nombre = ('zonas despobladas')
for key, df in dict_mun_desp.items():
    impact_analysis_per_service(df, key, nombre)
# Out:
# En el caso del servicio de md_SAAF, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de PORZUNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de MALAGUILLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de ARENAS DE SAN JUAN que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de PIEDRABUENA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de MINGLANILLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VINUELAS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLAMAYOR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CANETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VIANOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BELMONTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLAR DE OLALLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLANUEVA DE LOS INFANTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLARRUBIA DE SANTIAGO que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CORRAL DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRE DE JUAN ABAD que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MENASALBAS que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CIFUENTES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de RUIDERA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLATOBAS que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASAS DE FERNANDO ALONSO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BALAZOTE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SISANTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BARRAX que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BALLESTEROS DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HORCAJO DE LOS MONTES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLAHERMOSA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LLANOS DEL CAUDILLO que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de POZORRUBIO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASTELLAR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CABEZARADOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN CARLOS DEL VALLE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CALZADA DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HORCAJO DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de REILLO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLALBA DE LA SIERRA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LEDANA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRUBIA DEL CAMPO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PRIEGO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CAMPILLO DE ALTOBUEY que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLARTA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_AT, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de PORZUNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLAR DE OLALLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de PETROLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLARRUBIA DE SANTIAGO que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN PABLO DE LOS MONTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_EM, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de PORZUNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de AYNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SISANTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LUCIANA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PIEDRABUENA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUMANES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLANUEVA DE LOS INFANTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SANTA CRUZ DE MUDELA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CALZADA DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de RUIDERA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PRIEGO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_SO, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de MALAGUILLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto fuerte, ya que cuenta con 28 registros.
#
# La localidad de VINUELAS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de JADRAQUE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de BELMONTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de LEDANA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de SANTA CRUZ DE LA ZARZA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de MAHORA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de ONTUR que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CHILLARON DE CUENCA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CIFUENTES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SIGUENZA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SACEDON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de TEMBLEQUE que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de MENASALBAS que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CARBONERAS DE GUADAZAON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de PULGAR que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLARRUBIA DE SANTIAGO que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VIANOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de HIGUERUELA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de NAVALCAN que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SAN PABLO DE LOS MONTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CANETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TOTANES que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLATOBAS que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRUBIA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de NAVAHERMOSA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LAGARTERA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN MARTIN DE MONTALBAN que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VELADA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN MARTIN DE PUSA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN CARLOS DEL VALLE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLAMAYOR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLANUEVA DE LA JARA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MINAYA que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de RIOPAR que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BALAZOTE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SISANTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PORZUNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de INIESTA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASASIMARRO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de AYNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLAPALACIOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLALGORDO DEL JUCAR que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASAS DE BENITEZ que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLARTA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LEZUZA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SOCOVOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BIENSERVIDA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BOGARRA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CAMPILLO DE ALTOBUEY que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de FUENTEALBILLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BARRAX que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PIEDRABUENA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LUCIANA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de URDA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_LOG, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de VILLARRUBIA DE SANTIAGO que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de VILLATOBAS que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de PULGAR que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLAMAYOR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BONICHES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRUBIA DEL CAMPO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CANETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PRIEGO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_ACT, las localidades con impacto dentro de las que se incluyen en las zonas despobladas son:
#
# La localidad de MILLANA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de TRILLO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BRIHUEGA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BUENDIA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MOLINA DE ARAGON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de OREA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PRIEGO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.

# %%
# Iterando sobre el diccionario para crear gráficos y analizar impacto
nombre = ('zonas despobladas')
for key, df in dict_mun_desp.items():
    impact_analysis_depopulation(df, key, nombre)
# Out:
# En el caso del servicio de md_SAAF, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto fuerte, ya que cuenta con 28 registros.
#
# El tipo de zona de INTENSA DESPOBLACION que tiene un impacto fuerte, ya que cuenta con 24 registros.
#
# El tipo de zona de INTERMEDIA AGRICOLA que tiene un impacto leve, ya que cuenta con 5 registros.
#
# El tipo de zona de EN RIESGO que tiene un impacto leve, ya que cuenta con 3 registros.
#
#
#
# En el caso del servicio de md_AT, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto leve, ya que cuenta con 4 registros.
#
# El tipo de zona de INTENSA DESPOBLACION que tiene un impacto leve, ya que cuenta con 2 registros.
#
# El tipo de zona de EN RIESGO que tiene un impacto leve, ya que cuenta con 1 registro.
#
#
#
# En el caso del servicio de md_EM, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto medio, ya que cuenta con 7 registros.
#
# El tipo de zona de INTENSA DESPOBLACION que tiene un impacto leve, ya que cuenta con 5 registros.
#
#
#
# En el caso del servicio de md_SO, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto fuerte, ya que cuenta con 68 registros.
#
# El tipo de zona de INTENSA DESPOBLACION que tiene un impacto fuerte, ya que cuenta con 28 registros.
#
# El tipo de zona de EN RIESGO que tiene un impacto fuerte, ya que cuenta con 12 registros.
#
# El tipo de zona de INTERMEDIA AGRICOLA que tiene un impacto medio, ya que cuenta con 6 registros.
#
#
#
# En el caso del servicio de md_LOG, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EN RIESGO que tiene un impacto medio, ya que cuenta con 7 registros.
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto leve, ya que cuenta con 4 registros.
#
# El tipo de zona de INTENSA DESPOBLACION que tiene un impacto leve, ya que cuenta con 2 registros.
#
# El tipo de zona de INTERMEDIA AGRICOLA que tiene un impacto leve, ya que cuenta con 2 registros.
#
#
#
# En el caso del servicio de md_ACT, los números sobre el impacto para el tipo de zonas despobladas son:
#
# El tipo de zona de EXTREMA DESPOBLACION que tiene un impacto medio, ya que cuenta con 10 registros.

# %%
# Llamar a la función
result = pd.merge(result_df, mun_desp_clm, left_on='LOCALIDAD', right_on='MUNICIPIO')

impact_analysis(result)
# Out:
# Para todos los servicios de la provincia de Ciudad Real, las localidades con impacto dentro de las que se incluyen en los municipios de despoblación son:
#
# La localidad de MALAGUILLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto fuerte, ya que cuenta con 32 registros.
#
# La localidad de VILLARRUBIA DE SANTIAGO que pertenece a una zona EN RIESGO tiene un impacto medio, ya que cuenta con 10 registros.
#
# La localidad de PORZUNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto medio, ya que cuenta con 9 registros.
#
# La localidad de VINUELAS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto medio, ya que cuenta con 8 registros.
#
# La localidad de JADRAQUE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto medio, ya que cuenta con 6 registros.
#
# La localidad de PIEDRABUENA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de BELMONTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 5 registros.
#
# La localidad de LEDANA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de PULGAR que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de VIANOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de VILLATOBAS que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de PRIEGO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de VILLAMAYOR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de VILLAR DE OLALLA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de CANETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 4 registros.
#
# La localidad de SANTA CRUZ DE LA ZARZA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de MENASALBAS que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de CIFUENTES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de SISANTE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de ARENAS DE SAN JUAN que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de SAN PABLO DE LOS MONTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de VILLANUEVA DE LOS INFANTES que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de HUETE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 3 registros.
#
# La localidad de CARBONERAS DE GUADAZAON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de TRILLO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de VILLARTA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BARRAX que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de MAHORA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de AYNA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de LUCIANA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BALAZOTE que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CHILLARON DE CUENCA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de ONTUR que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de MILLANA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de BRIHUEGA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de MINGLANILLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SIGUENZA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SAN CARLOS DEL VALLE que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CAMPILLO DE ALTOBUEY que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de TORRUBIA DEL CAMPO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de NAVALCAN que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de CALZADA DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de HIGUERUELA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de RUIDERA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de SACEDON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de TEMBLEQUE que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 2 registros.
#
# La localidad de LAGARTERA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLALGORDO DEL JUCAR que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASAS DE BENITEZ que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LEZUZA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SOCOVOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TOTANES que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VELADA que pertenece a una zona EN RIESGO tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN MARTIN DE PUSA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BIENSERVIDA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BOGARRA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLAPALACIOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRUBIA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SAN MARTIN DE MONTALBAN que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de NAVAHERMOSA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de FUENTEALBILLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BONICHES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASASIMARRO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de TORRE DE JUAN ABAD que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLALBA DE LA SIERRA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de REILLO que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HORCAJO DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CABEZARADOS que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASTELLAR DE SANTIAGO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HORCAJO DE LOS MONTES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de LLANOS DEL CAUDILLO que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLAHERMOSA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BALLESTEROS DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CORRAL DE CALATRAVA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de CASAS DE FERNANDO ALONSO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de INIESTA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de PETROLA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de POZORRUBIO que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de HUMANES que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de SANTA CRUZ DE MUDELA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de BUENDIA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MOLINA DE ARAGON que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de OREA que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de VILLANUEVA DE LA JARA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de MINAYA que pertenece a una zona INTERMEDIA AGRICOLA tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de RIOPAR que pertenece a una zona EXTREMA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.
#
# La localidad de URDA que pertenece a una zona INTENSA DESPOBLACION tiene un impacto leve, ya que cuenta con 1 registro.

# %% [markdown]
# ## Áreas de Salud

# %% [markdown]
# Código de Áreas de Salud no contemplado para el PFG, dejar para FASPAS.

# %%
dict_areas_salud = {
    'as_SAAF': pd.merge(SAAF, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR'),
    'as_AT': pd.merge(AT, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR'),
    'as_EM': pd.merge(EM, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR'),
    'as_SO': pd.merge(SO, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR'),
    'as_ACT': pd.merge(ACT, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR'),
    'as_LOG': pd.merge(LOG, areas_clm, left_on='LOCALIDAD', right_on='ENTIDAD SINGULAR')
}

# %%
# Iterando sobre el diccionario para crear gráficos
for key, df in dict_areas_salud.items():
    # Calcular el conteo de registros para cada categoría
    cat_count = df['AREA DE SALUD'].value_counts()

    plt.figure(figsize=(12, 5))  # Width=12 inches and Height=5 inches
    # Crear un gráfico de barras
    ax = cat_count.sort_index().plot(kind='bar')

    # Personalización adicional
    plt.title(f'{key}: Impacto en Áreas por Áreas de Salud')
    plt.xlabel('ÁREA DE SALUD')
    plt.ylabel('Número de Registros')
    plt.xticks(rotation=45, ha = 'right')  # Rota las etiquetas del eje X para mejor lectura
    plt.xticks(fontsize=10)

    # Añadir el número de conteos en la parte superior de cada barra
    for i in ax.containers:
        ax.bar_label(i, label_type='edge')

    # Mostrar el gráfico
    plt.show()
